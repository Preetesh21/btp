# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
#Set Parameters
im_width = 256
im_height = 256

# %% [markdown]
# # **Load image's path and mask's path**

# %%
train_files = []
mask_files = glob('../input/lgg-mri-segmentation/kaggle_3m/*/*_mask*')

for i in mask_files:
    train_files.append(i.replace('_mask',''))

print(train_files[:10])
print(mask_files[:10])
# Out:
# ['../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_8.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_34.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_33.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_43.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_39.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_7.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_31.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_6.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_38.tif']
# ['../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_8_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_34_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_33_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_43_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_39_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_7_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_31_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_6_mask.tif', '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_38_mask.tif']

# %% [markdown]
# # **Data Visualization**

# %%
#Lets plot some samples
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=train_files[i]
    msk_path=mask_files[i]
    img=cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %% [markdown]
# # **Create data frame and split data on train set, validation set and test set**

# %%
def diagnosis(mask_path):
    value = np.max(cv2.imread(mask_path))
    return '1' if value > 0 else '0'
df = pd.DataFrame({"image_path": train_files,
                   "mask_path": mask_files,
                  "diagnosis":[diagnosis(x) for x in mask_files]})
df.head()
# Out:
#                                           image_path  \
# 0  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 1  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 2  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 3  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 4  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
#
#                                            mask_path diagnosis
# 0  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...         0
# 1  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...         0
# 2  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...         1
# 3  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...         1
# 4  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...         1

# %%
# Plot
ax = df.diagnosis.value_counts().plot(kind='bar',
                                      stacked=True,
                                      figsize=(10, 6),
                                     color=["violet", "lightseagreen"])


ax.set_xticklabels(["Positive", "Negative"], rotation=45, fontsize=12);
ax.set_ylabel('Total Images', fontsize = 12)
ax.set_title("Distribution of data grouped by diagnosis",fontsize = 18, y=1.05)

# Annotate
for i, rows in enumerate(df.diagnosis.value_counts().values):
    ax.annotate(int(rows), xy=(i, rows-12), 
                rotation=0, color="white", 
                ha="center", verticalalignment='bottom', 
                fontsize=15, fontweight="bold")
    
ax.text(1.2, 2550, f"Total {len(df)} images", size=15,
        color="black",
         ha="center", va="center",
         bbox=dict(boxstyle="round",
                   fc=("lightblue"),
                   ec=("black"),
                   )
         );

# %%
df = pd.DataFrame(data={"filename": train_files, 'mask' : mask_files})
df_train, df_test = train_test_split(df,test_size = 0.1)
df_train, df_val = train_test_split(df_train,test_size = 0.2)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (2828, 2)
# (708, 2)
# (393, 2)

# %% [markdown]
# # **Data genertator, data augmentation and adjust data**

# %%
# From: https://github.com/zhixuhao/unet/blob/master/data.py
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    '''
    can generate image and mask at the same time use the same seed for
    image_datagen and mask_datagen to ensure the transformation for image
    and mask is the same if you want to visualize the results of generator,
    set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %% [markdown]
# # **Define loss function and metrics**

# %%
smooth=100

def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def jac_distance(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)

    return - iou(y_true, y_pred)

# %% [markdown]
# # **Define Unet**

# %%
def unet(input_size=(256,256,3)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(64, (3, 3), padding='same')(inputs)
    bn1 = Activation('relu')(conv1)
    conv1 = Conv2D(64, (3, 3), padding='same')(bn1)
    bn1 = BatchNormalization(axis=3)(conv1)
    bn1 = Activation('relu')(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)

    conv2 = Conv2D(128, (3, 3), padding='same')(pool1)
    bn2 = Activation('relu')(conv2)
    conv2 = Conv2D(128, (3, 3), padding='same')(bn2)
    bn2 = BatchNormalization(axis=3)(conv2)
    bn2 = Activation('relu')(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)

    conv3 = Conv2D(256, (3, 3), padding='same')(pool2)
    bn3 = Activation('relu')(conv3)
    conv3 = Conv2D(256, (3, 3), padding='same')(bn3)
    bn3 = BatchNormalization(axis=3)(conv3)
    bn3 = Activation('relu')(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)

    conv4 = Conv2D(512, (3, 3), padding='same')(pool3)
    bn4 = Activation('relu')(conv4)
    conv4 = Conv2D(512, (3, 3), padding='same')(bn4)
    bn4 = BatchNormalization(axis=3)(conv4)
    bn4 = Activation('relu')(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = Conv2D(1024, (3, 3), padding='same')(pool4)
    bn5 = Activation('relu')(conv5)
    conv5 = Conv2D(1024, (3, 3), padding='same')(bn5)
    bn5 = BatchNormalization(axis=3)(conv5)
    bn5 = Activation('relu')(bn5)

    up6 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bn5), conv4], axis=3)
    conv6 = Conv2D(512, (3, 3), padding='same')(up6)
    bn6 = Activation('relu')(conv6)
    conv6 = Conv2D(512, (3, 3), padding='same')(bn6)
    bn6 = BatchNormalization(axis=3)(conv6)
    bn6 = Activation('relu')(bn6)

    up7 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bn6), conv3], axis=3)
    conv7 = Conv2D(256, (3, 3), padding='same')(up7)
    bn7 = Activation('relu')(conv7)
    conv7 = Conv2D(256, (3, 3), padding='same')(bn7)
    bn7 = BatchNormalization(axis=3)(conv7)
    bn7 = Activation('relu')(bn7)

    up8 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(bn7), conv2], axis=3)
    conv8 = Conv2D(128, (3, 3), padding='same')(up8)
    bn8 = Activation('relu')(conv8)
    conv8 = Conv2D(128, (3, 3), padding='same')(bn8)
    bn8 = BatchNormalization(axis=3)(conv8)
    bn8 = Activation('relu')(bn8)

    up9 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bn8), conv1], axis=3)
    conv9 = Conv2D(64, (3, 3), padding='same')(up9)
    bn9 = Activation('relu')(conv9)
    conv9 = Conv2D(64, (3, 3), padding='same')(bn9)
    bn9 = BatchNormalization(axis=3)(conv9)
    bn9 = Activation('relu')(bn9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
model = unet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 128 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 256)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 512)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 1024) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 1024) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 512)  2097664     activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 512)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  2359808     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 512)  2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  524544      activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 256)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  590080      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 131200      activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 128, 128 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 128 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 32832       activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 256, 256, 64) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 64) 36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 256, 256, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 256, 64) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  65          activation_17[0][0]
# ==================================================================================================
# Total params: 31,043,521
# Trainable params: 31,037,633
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# # **Training**

# %%
EPOCHS = 100
BATCH_SIZE = 32
learning_rate = 1e-4

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=(im_height, im_width))
    
test_gener = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
    
model = unet(input_size=(im_height, im_width, 3))



decay_rate = learning_rate / EPOCHS
opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=decay_rate, amsgrad=False)
model.compile(optimizer=opt, loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

callbacks = [ModelCheckpoint('unet_brain_mri_seg.hdf5', verbose=1, save_best_only=True)]

history = model.fit(train_gen,
                    steps_per_epoch=len(df_train) / BATCH_SIZE, 
                    epochs=EPOCHS, 
                    callbacks=callbacks,
                    validation_data = test_gener,
                    validation_steps=len(df_val) / BATCH_SIZE)
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# Epoch 1/100
# 89/88 [==============================] - ETA: 0s - loss: -0.1008 - binary_accuracy: 0.8980 - iou: 0.0545 - dice_coef: 0.1015Found 708 validated image filenames.
# Found 708 validated image filenames.
#
# Epoch 00001: val_loss improved from inf to -0.02870, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 110s 1s/step - loss: -0.1008 - binary_accuracy: 0.8980 - iou: 0.0545 - dice_coef: 0.1015 - val_loss: -0.0287 - val_binary_accuracy: 0.1673 - val_iou: 0.0141 - val_dice_coef: 0.0276
# Epoch 2/100
# 89/88 [==============================] - ETA: 0s - loss: -0.1708 - binary_accuracy: 0.9821 - iou: 0.0949 - dice_coef: 0.1715
# Epoch 00002: val_loss did not improve from -0.02870
# 89/88 [==============================] - 88s 987ms/step - loss: -0.1708 - binary_accuracy: 0.9821 - iou: 0.0949 - dice_coef: 0.1715 - val_loss: -0.0243 - val_binary_accuracy: 0.8561 - val_iou: 0.0121 - val_dice_coef: 0.0236
# Epoch 3/100
# 89/88 [==============================] - ETA: 0s - loss: -0.2193 - binary_accuracy: 0.9879 - iou: 0.1243 - dice_coef: 0.2182
# Epoch 00003: val_loss improved from -0.02870 to -0.04762, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 88s 986ms/step - loss: -0.2193 - binary_accuracy: 0.9879 - iou: 0.1243 - dice_coef: 0.2182 - val_loss: -0.0476 - val_binary_accuracy: 0.9902 - val_iou: 0.0285 - val_dice_coef: 0.0539
# Epoch 4/100
# 89/88 [==============================] - ETA: 0s - loss: -0.2672 - binary_accuracy: 0.9903 - iou: 0.1558 - dice_coef: 0.2664
# Epoch 00004: val_loss did not improve from -0.04762
# 89/88 [==============================] - 87s 979ms/step - loss: -0.2672 - binary_accuracy: 0.9903 - iou: 0.1558 - dice_coef: 0.2664 - val_loss: -0.0428 - val_binary_accuracy: 0.9395 - val_iou: 0.0218 - val_dice_coef: 0.0418
# Epoch 5/100
# 89/88 [==============================] - ETA: 0s - loss: -0.3191 - binary_accuracy: 0.9914 - iou: 0.1926 - dice_coef: 0.3191
# Epoch 00005: val_loss improved from -0.04762 to -0.11956, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 89s 996ms/step - loss: -0.3191 - binary_accuracy: 0.9914 - iou: 0.1926 - dice_coef: 0.3191 - val_loss: -0.1196 - val_binary_accuracy: 0.9067 - val_iou: 0.0620 - val_dice_coef: 0.1153
# Epoch 6/100
# 89/88 [==============================] - ETA: 0s - loss: -0.3772 - binary_accuracy: 0.9930 - iou: 0.2361 - dice_coef: 0.3771
# Epoch 00006: val_loss improved from -0.11956 to -0.38939, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 90s 1s/step - loss: -0.3772 - binary_accuracy: 0.9930 - iou: 0.2361 - dice_coef: 0.3771 - val_loss: -0.3894 - val_binary_accuracy: 0.9908 - val_iou: 0.2367 - val_dice_coef: 0.3754
# Epoch 7/100
# 89/88 [==============================] - ETA: 0s - loss: -0.4438 - binary_accuracy: 0.9943 - iou: 0.2898 - dice_coef: 0.4442
# Epoch 00007: val_loss improved from -0.38939 to -0.45648, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 89s 1s/step - loss: -0.4438 - binary_accuracy: 0.9943 - iou: 0.2898 - dice_coef: 0.4442 - val_loss: -0.4565 - val_binary_accuracy: 0.9952 - val_iou: 0.2900 - val_dice_coef: 0.4404
# Epoch 8/100
# 89/88 [==============================] - ETA: 0s - loss: -0.4969 - binary_accuracy: 0.9948 - iou: 0.3372 - dice_coef: 0.4972
# Epoch 00008: val_loss improved from -0.45648 to -0.58988, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 87s 978ms/step - loss: -0.4969 - binary_accuracy: 0.9948 - iou: 0.3372 - dice_coef: 0.4972 - val_loss: -0.5899 - val_binary_accuracy: 0.9942 - val_iou: 0.4097 - val_dice_coef: 0.5692
# Epoch 9/100
# 89/88 [==============================] - ETA: 0s - loss: -0.5526 - binary_accuracy: 0.9953 - iou: 0.3880 - dice_coef: 0.5526
# Epoch 00009: val_loss did not improve from -0.58988
# 89/88 [==============================] - 87s 979ms/step - loss: -0.5526 - binary_accuracy: 0.9953 - iou: 0.3880 - dice_coef: 0.5526 - val_loss: -0.5541 - val_binary_accuracy: 0.9902 - val_iou: 0.3772 - val_dice_coef: 0.5401
# Epoch 10/100
# 89/88 [==============================] - ETA: 0s - loss: -0.6049 - binary_accuracy: 0.9958 - iou: 0.4395 - dice_coef: 0.6044
# Epoch 00010: val_loss did not improve from -0.58988
# 89/88 [==============================] - 86s 967ms/step - loss: -0.6049 - binary_accuracy: 0.9958 - iou: 0.4395 - dice_coef: 0.6044 - val_loss: -0.5078 - val_binary_accuracy: 0.9947 - val_iou: 0.3349 - val_dice_coef: 0.4905
# Epoch 11/100
# 89/88 [==============================] - ETA: 0s - loss: -0.6430 - binary_accuracy: 0.9960 - iou: 0.4800 - dice_coef: 0.6440
# Epoch 00011: val_loss improved from -0.58988 to -0.67492, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 87s 983ms/step - loss: -0.6430 - binary_accuracy: 0.9960 - iou: 0.4800 - dice_coef: 0.6440 - val_loss: -0.6749 - val_binary_accuracy: 0.9964 - val_iou: 0.5010 - val_dice_coef: 0.6525
# Epoch 12/100
# 89/88 [==============================] - ETA: 0s - loss: -0.6787 - binary_accuracy: 0.9963 - iou: 0.5189 - dice_coef: 0.6785
# Epoch 00012: val_loss improved from -0.67492 to -0.72988, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 88s 984ms/step - loss: -0.6787 - binary_accuracy: 0.9963 - iou: 0.5189 - dice_coef: 0.6785 - val_loss: -0.7299 - val_binary_accuracy: 0.9965 - val_iou: 0.5811 - val_dice_coef: 0.7326
# Epoch 13/100
# 89/88 [==============================] - ETA: 0s - loss: -0.7064 - binary_accuracy: 0.9965 - iou: 0.5534 - dice_coef: 0.7068
# Epoch 00013: val_loss improved from -0.72988 to -0.73269, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 87s 980ms/step - loss: -0.7064 - binary_accuracy: 0.9965 - iou: 0.5534 - dice_coef: 0.7068 - val_loss: -0.7327 - val_binary_accuracy: 0.9960 - val_iou: 0.5865 - val_dice_coef: 0.7365
# Epoch 14/100
# 89/88 [==============================] - ETA: 0s - loss: -0.7030 - binary_accuracy: 0.9960 - iou: 0.5489 - dice_coef: 0.7032
# Epoch 00014: val_loss improved from -0.73269 to -0.75989, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 86s 971ms/step - loss: -0.7030 - binary_accuracy: 0.9960 - iou: 0.5489 - dice_coef: 0.7032 - val_loss: -0.7599 - val_binary_accuracy: 0.9963 - val_iou: 0.6019 - val_dice_coef: 0.7433
# Epoch 15/100
# 89/88 [==============================] - ETA: 0s - loss: -0.7589 - binary_accuracy: 0.9969 - iou: 0.6154 - dice_coef: 0.7587
# Epoch 00015: val_loss did not improve from -0.75989
# 89/88 [==============================] - 87s 973ms/step - loss: -0.7589 - binary_accuracy: 0.9969 - iou: 0.6154 - dice_coef: 0.7587 - val_loss: -0.7590 - val_binary_accuracy: 0.9968 - val_iou: 0.6110 - val_dice_coef: 0.7537
# Epoch 16/100
# 89/88 [==============================] - ETA: 0s - loss: -0.7645 - binary_accuracy: 0.9969 - iou: 0.6255 - dice_coef: 0.7647
# Epoch 00016: val_loss improved from -0.75989 to -0.79064, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 87s 979ms/step - loss: -0.7645 - binary_accuracy: 0.9969 - iou: 0.6255 - dice_coef: 0.7647 - val_loss: -0.7906 - val_binary_accuracy: 0.9973 - val_iou: 0.6424 - val_dice_coef: 0.7682
# Epoch 17/100
# 89/88 [==============================] - ETA: 0s - loss: -0.7825 - binary_accuracy: 0.9970 - iou: 0.6478 - dice_coef: 0.7819
# Epoch 00017: val_loss did not improve from -0.79064
# 89/88 [==============================] - 86s 966ms/step - loss: -0.7825 - binary_accuracy: 0.9970 - iou: 0.6478 - dice_coef: 0.7819 - val_loss: -0.7902 - val_binary_accuracy: 0.9967 - val_iou: 0.6618 - val_dice_coef: 0.7938
# Epoch 18/100
# 89/88 [==============================] - ETA: 0s - loss: -0.7976 - binary_accuracy: 0.9971 - iou: 0.6674 - dice_coef: 0.7978
# Epoch 00018: val_loss improved from -0.79064 to -0.80155, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 87s 981ms/step - loss: -0.7976 - binary_accuracy: 0.9971 - iou: 0.6674 - dice_coef: 0.7978 - val_loss: -0.8015 - val_binary_accuracy: 0.9973 - val_iou: 0.6595 - val_dice_coef: 0.7799
# Epoch 19/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8034 - binary_accuracy: 0.9971 - iou: 0.6783 - dice_coef: 0.8034
# Epoch 00019: val_loss improved from -0.80155 to -0.80335, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 87s 980ms/step - loss: -0.8034 - binary_accuracy: 0.9971 - iou: 0.6783 - dice_coef: 0.8034 - val_loss: -0.8034 - val_binary_accuracy: 0.9965 - val_iou: 0.6823 - val_dice_coef: 0.8082
# Epoch 20/100
# 89/88 [==============================] - ETA: 0s - loss: -0.7893 - binary_accuracy: 0.9968 - iou: 0.6584 - dice_coef: 0.7898
# Epoch 00020: val_loss improved from -0.80335 to -0.80477, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 87s 973ms/step - loss: -0.7893 - binary_accuracy: 0.9968 - iou: 0.6584 - dice_coef: 0.7898 - val_loss: -0.8048 - val_binary_accuracy: 0.9971 - val_iou: 0.6833 - val_dice_coef: 0.8067
# Epoch 21/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8159 - binary_accuracy: 0.9972 - iou: 0.6942 - dice_coef: 0.8160
# Epoch 00021: val_loss improved from -0.80477 to -0.82259, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 87s 978ms/step - loss: -0.8159 - binary_accuracy: 0.9972 - iou: 0.6942 - dice_coef: 0.8160 - val_loss: -0.8226 - val_binary_accuracy: 0.9969 - val_iou: 0.7042 - val_dice_coef: 0.8243
# Epoch 22/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8284 - binary_accuracy: 0.9973 - iou: 0.7092 - dice_coef: 0.8276
# Epoch 00022: val_loss improved from -0.82259 to -0.83327, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 87s 973ms/step - loss: -0.8284 - binary_accuracy: 0.9973 - iou: 0.7092 - dice_coef: 0.8276 - val_loss: -0.8333 - val_binary_accuracy: 0.9971 - val_iou: 0.7210 - val_dice_coef: 0.8362
# Epoch 23/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8216 - binary_accuracy: 0.9972 - iou: 0.7045 - dice_coef: 0.8210
# Epoch 00023: val_loss improved from -0.83327 to -0.83369, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 87s 978ms/step - loss: -0.8216 - binary_accuracy: 0.9972 - iou: 0.7045 - dice_coef: 0.8210 - val_loss: -0.8337 - val_binary_accuracy: 0.9971 - val_iou: 0.7099 - val_dice_coef: 0.8273
# Epoch 24/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8323 - binary_accuracy: 0.9973 - iou: 0.7174 - dice_coef: 0.8318
# Epoch 00024: val_loss improved from -0.83369 to -0.84072, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 87s 980ms/step - loss: -0.8323 - binary_accuracy: 0.9973 - iou: 0.7174 - dice_coef: 0.8318 - val_loss: -0.8407 - val_binary_accuracy: 0.9972 - val_iou: 0.7316 - val_dice_coef: 0.8424
# Epoch 25/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8388 - binary_accuracy: 0.9974 - iou: 0.7270 - dice_coef: 0.8391
# Epoch 00025: val_loss did not improve from -0.84072
# 89/88 [==============================] - 86s 969ms/step - loss: -0.8388 - binary_accuracy: 0.9974 - iou: 0.7270 - dice_coef: 0.8391 - val_loss: -0.8393 - val_binary_accuracy: 0.9971 - val_iou: 0.7308 - val_dice_coef: 0.8423
# Epoch 26/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8330 - binary_accuracy: 0.9972 - iou: 0.7223 - dice_coef: 0.8328
# Epoch 00026: val_loss did not improve from -0.84072
# 89/88 [==============================] - 86s 961ms/step - loss: -0.8330 - binary_accuracy: 0.9972 - iou: 0.7223 - dice_coef: 0.8328 - val_loss: -0.5673 - val_binary_accuracy: 0.9933 - val_iou: 0.3945 - val_dice_coef: 0.5551
# Epoch 27/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8226 - binary_accuracy: 0.9970 - iou: 0.7014 - dice_coef: 0.8196
# Epoch 00027: val_loss did not improve from -0.84072
# 89/88 [==============================] - 86s 971ms/step - loss: -0.8226 - binary_accuracy: 0.9970 - iou: 0.7014 - dice_coef: 0.8196 - val_loss: -0.8355 - val_binary_accuracy: 0.9969 - val_iou: 0.7247 - val_dice_coef: 0.8382
# Epoch 28/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8535 - binary_accuracy: 0.9975 - iou: 0.7474 - dice_coef: 0.8529
# Epoch 00028: val_loss improved from -0.84072 to -0.84544, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 87s 974ms/step - loss: -0.8535 - binary_accuracy: 0.9975 - iou: 0.7474 - dice_coef: 0.8529 - val_loss: -0.8454 - val_binary_accuracy: 0.9969 - val_iou: 0.7184 - val_dice_coef: 0.8277
# Epoch 29/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8474 - binary_accuracy: 0.9974 - iou: 0.7379 - dice_coef: 0.8461
# Epoch 00029: val_loss did not improve from -0.84544
# 89/88 [==============================] - 87s 974ms/step - loss: -0.8474 - binary_accuracy: 0.9974 - iou: 0.7379 - dice_coef: 0.8461 - val_loss: -0.8198 - val_binary_accuracy: 0.9966 - val_iou: 0.7047 - val_dice_coef: 0.8238
# Epoch 30/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8122 - binary_accuracy: 0.9967 - iou: 0.6916 - dice_coef: 0.8126
# Epoch 00030: val_loss did not improve from -0.84544
# 89/88 [==============================] - 86s 964ms/step - loss: -0.8122 - binary_accuracy: 0.9967 - iou: 0.6916 - dice_coef: 0.8126 - val_loss: -0.8276 - val_binary_accuracy: 0.9970 - val_iou: 0.7042 - val_dice_coef: 0.8163
# Epoch 31/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8472 - binary_accuracy: 0.9973 - iou: 0.7426 - dice_coef: 0.8472
# Epoch 00031: val_loss improved from -0.84544 to -0.86385, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 88s 986ms/step - loss: -0.8472 - binary_accuracy: 0.9973 - iou: 0.7426 - dice_coef: 0.8472 - val_loss: -0.8638 - val_binary_accuracy: 0.9972 - val_iou: 0.7574 - val_dice_coef: 0.8531
# Epoch 32/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8537 - binary_accuracy: 0.9974 - iou: 0.7515 - dice_coef: 0.8540
# Epoch 00032: val_loss did not improve from -0.86385
# 89/88 [==============================] - 87s 975ms/step - loss: -0.8537 - binary_accuracy: 0.9974 - iou: 0.7515 - dice_coef: 0.8540 - val_loss: -0.7580 - val_binary_accuracy: 0.9957 - val_iou: 0.6306 - val_dice_coef: 0.7639
# Epoch 33/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8571 - binary_accuracy: 0.9975 - iou: 0.7572 - dice_coef: 0.8565
# Epoch 00033: val_loss improved from -0.86385 to -0.86783, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 88s 984ms/step - loss: -0.8571 - binary_accuracy: 0.9975 - iou: 0.7572 - dice_coef: 0.8565 - val_loss: -0.8678 - val_binary_accuracy: 0.9976 - val_iou: 0.7641 - val_dice_coef: 0.8584
# Epoch 34/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8584 - binary_accuracy: 0.9974 - iou: 0.7562 - dice_coef: 0.8588
# Epoch 00034: val_loss did not improve from -0.86783
# 89/88 [==============================] - 86s 966ms/step - loss: -0.8584 - binary_accuracy: 0.9974 - iou: 0.7562 - dice_coef: 0.8588 - val_loss: -0.8156 - val_binary_accuracy: 0.9965 - val_iou: 0.6943 - val_dice_coef: 0.8166
# Epoch 35/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8646 - binary_accuracy: 0.9975 - iou: 0.7658 - dice_coef: 0.8649
# Epoch 00035: val_loss improved from -0.86783 to -0.87220, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 88s 986ms/step - loss: -0.8646 - binary_accuracy: 0.9975 - iou: 0.7658 - dice_coef: 0.8649 - val_loss: -0.8722 - val_binary_accuracy: 0.9977 - val_iou: 0.7795 - val_dice_coef: 0.8748
# Epoch 36/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8803 - binary_accuracy: 0.9978 - iou: 0.7886 - dice_coef: 0.8804
# Epoch 00036: val_loss improved from -0.87220 to -0.88681, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 89s 1s/step - loss: -0.8803 - binary_accuracy: 0.9978 - iou: 0.7886 - dice_coef: 0.8804 - val_loss: -0.8868 - val_binary_accuracy: 0.9976 - val_iou: 0.8011 - val_dice_coef: 0.8886
# Epoch 37/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8748 - binary_accuracy: 0.9977 - iou: 0.7817 - dice_coef: 0.8739
# Epoch 00037: val_loss did not improve from -0.88681
# 89/88 [==============================] - 87s 973ms/step - loss: -0.8748 - binary_accuracy: 0.9977 - iou: 0.7817 - dice_coef: 0.8739 - val_loss: -0.8725 - val_binary_accuracy: 0.9975 - val_iou: 0.7804 - val_dice_coef: 0.8754
# Epoch 38/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8775 - binary_accuracy: 0.9978 - iou: 0.7877 - dice_coef: 0.8780
# Epoch 00038: val_loss did not improve from -0.88681
# 89/88 [==============================] - 86s 972ms/step - loss: -0.8775 - binary_accuracy: 0.9978 - iou: 0.7877 - dice_coef: 0.8780 - val_loss: -0.8840 - val_binary_accuracy: 0.9977 - val_iou: 0.7965 - val_dice_coef: 0.8859
# Epoch 39/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8863 - binary_accuracy: 0.9979 - iou: 0.7996 - dice_coef: 0.8865
# Epoch 00039: val_loss did not improve from -0.88681
# 89/88 [==============================] - 87s 981ms/step - loss: -0.8863 - binary_accuracy: 0.9979 - iou: 0.7996 - dice_coef: 0.8865 - val_loss: -0.8830 - val_binary_accuracy: 0.9977 - val_iou: 0.7942 - val_dice_coef: 0.8840
# Epoch 40/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8845 - binary_accuracy: 0.9979 - iou: 0.7976 - dice_coef: 0.8849
# Epoch 00040: val_loss did not improve from -0.88681
# 89/88 [==============================] - 86s 967ms/step - loss: -0.8845 - binary_accuracy: 0.9979 - iou: 0.7976 - dice_coef: 0.8849 - val_loss: -0.8827 - val_binary_accuracy: 0.9979 - val_iou: 0.7934 - val_dice_coef: 0.8831
# Epoch 41/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8856 - binary_accuracy: 0.9980 - iou: 0.8007 - dice_coef: 0.8854
# Epoch 00041: val_loss improved from -0.88681 to -0.90178, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 88s 984ms/step - loss: -0.8856 - binary_accuracy: 0.9980 - iou: 0.8007 - dice_coef: 0.8854 - val_loss: -0.9018 - val_binary_accuracy: 0.9978 - val_iou: 0.8210 - val_dice_coef: 0.8965
# Epoch 42/100
# 89/88 [==============================] - ETA: 0s - loss: -0.0595 - binary_accuracy: 0.9264 - iou: 0.0317 - dice_coef: 0.0595
# Epoch 00042: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.0595 - binary_accuracy: 0.9264 - iou: 0.0317 - dice_coef: 0.0595 - val_loss: -0.5740 - val_binary_accuracy: 0.9848 - val_iou: 0.4073 - val_dice_coef: 0.5752
# Epoch 43/100
# 89/88 [==============================] - ETA: 0s - loss: -0.0754 - binary_accuracy: 0.9095 - iou: 0.0398 - dice_coef: 0.0753
# Epoch 00043: val_loss did not improve from -0.90178
# 89/88 [==============================] - 92s 1s/step - loss: -0.0754 - binary_accuracy: 0.9095 - iou: 0.0398 - dice_coef: 0.0753 - val_loss: -0.2500 - val_binary_accuracy: 0.9429 - val_iou: 0.1431 - val_dice_coef: 0.2465
# Epoch 44/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8324 - binary_accuracy: 0.9939 - iou: 0.7363 - dice_coef: 0.8332
# Epoch 00044: val_loss did not improve from -0.90178
# 89/88 [==============================] - 91s 1s/step - loss: -0.8324 - binary_accuracy: 0.9939 - iou: 0.7363 - dice_coef: 0.8332 - val_loss: -0.8783 - val_binary_accuracy: 0.9976 - val_iou: 0.7785 - val_dice_coef: 0.8674
# Epoch 45/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8783 - binary_accuracy: 0.9978 - iou: 0.7902 - dice_coef: 0.8786
# Epoch 00045: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.8783 - binary_accuracy: 0.9978 - iou: 0.7902 - dice_coef: 0.8786 - val_loss: -0.8769 - val_binary_accuracy: 0.9977 - val_iou: 0.7858 - val_dice_coef: 0.8779
# Epoch 46/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8870 - binary_accuracy: 0.9979 - iou: 0.8005 - dice_coef: 0.8868
# Epoch 00046: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.8870 - binary_accuracy: 0.9979 - iou: 0.8005 - dice_coef: 0.8868 - val_loss: -0.8904 - val_binary_accuracy: 0.9978 - val_iou: 0.8047 - val_dice_coef: 0.8908
# Epoch 47/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8815 - binary_accuracy: 0.9977 - iou: 0.7919 - dice_coef: 0.8808
# Epoch 00047: val_loss did not improve from -0.90178
# 89/88 [==============================] - 95s 1s/step - loss: -0.8815 - binary_accuracy: 0.9977 - iou: 0.7919 - dice_coef: 0.8808 - val_loss: -0.8884 - val_binary_accuracy: 0.9978 - val_iou: 0.8041 - val_dice_coef: 0.8905
# Epoch 48/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8811 - binary_accuracy: 0.9977 - iou: 0.7943 - dice_coef: 0.8809
# Epoch 00048: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.8811 - binary_accuracy: 0.9977 - iou: 0.7943 - dice_coef: 0.8809 - val_loss: -0.8956 - val_binary_accuracy: 0.9977 - val_iou: 0.8145 - val_dice_coef: 0.8970
# Epoch 49/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8912 - binary_accuracy: 0.9979 - iou: 0.8078 - dice_coef: 0.8915
# Epoch 00049: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.8912 - binary_accuracy: 0.9979 - iou: 0.8078 - dice_coef: 0.8915 - val_loss: -0.8948 - val_binary_accuracy: 0.9979 - val_iou: 0.8120 - val_dice_coef: 0.8913
# Epoch 50/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8879 - binary_accuracy: 0.9978 - iou: 0.8045 - dice_coef: 0.8883
# Epoch 00050: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.8879 - binary_accuracy: 0.9978 - iou: 0.8045 - dice_coef: 0.8883 - val_loss: -0.8709 - val_binary_accuracy: 0.9972 - val_iou: 0.7633 - val_dice_coef: 0.8632
# Epoch 51/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8887 - binary_accuracy: 0.9979 - iou: 0.8058 - dice_coef: 0.8888
# Epoch 00051: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.8887 - binary_accuracy: 0.9979 - iou: 0.8058 - dice_coef: 0.8888 - val_loss: -0.8798 - val_binary_accuracy: 0.9974 - val_iou: 0.7882 - val_dice_coef: 0.8802
# Epoch 52/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8858 - binary_accuracy: 0.9978 - iou: 0.7983 - dice_coef: 0.8860
# Epoch 00052: val_loss did not improve from -0.90178
# 89/88 [==============================] - 91s 1s/step - loss: -0.8858 - binary_accuracy: 0.9978 - iou: 0.7983 - dice_coef: 0.8860 - val_loss: -0.8792 - val_binary_accuracy: 0.9977 - val_iou: 0.7783 - val_dice_coef: 0.8725
# Epoch 53/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8843 - binary_accuracy: 0.9978 - iou: 0.8000 - dice_coef: 0.8845
# Epoch 00053: val_loss did not improve from -0.90178
# 89/88 [==============================] - 91s 1s/step - loss: -0.8843 - binary_accuracy: 0.9978 - iou: 0.8000 - dice_coef: 0.8845 - val_loss: -0.8744 - val_binary_accuracy: 0.9974 - val_iou: 0.7831 - val_dice_coef: 0.8765
# Epoch 54/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8770 - binary_accuracy: 0.9976 - iou: 0.7871 - dice_coef: 0.8773
# Epoch 00054: val_loss did not improve from -0.90178
# 89/88 [==============================] - 89s 1s/step - loss: -0.8770 - binary_accuracy: 0.9976 - iou: 0.7871 - dice_coef: 0.8773 - val_loss: -0.8757 - val_binary_accuracy: 0.9977 - val_iou: 0.7585 - val_dice_coef: 0.8457
# Epoch 55/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8884 - binary_accuracy: 0.9978 - iou: 0.8034 - dice_coef: 0.8887
# Epoch 00055: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.8884 - binary_accuracy: 0.9978 - iou: 0.8034 - dice_coef: 0.8887 - val_loss: -0.8968 - val_binary_accuracy: 0.9978 - val_iou: 0.8192 - val_dice_coef: 0.8993
# Epoch 56/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8984 - binary_accuracy: 0.9980 - iou: 0.8181 - dice_coef: 0.8985
# Epoch 00056: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.8984 - binary_accuracy: 0.9980 - iou: 0.8181 - dice_coef: 0.8985 - val_loss: -0.8982 - val_binary_accuracy: 0.9977 - val_iou: 0.8183 - val_dice_coef: 0.8990
# Epoch 57/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8989 - binary_accuracy: 0.9980 - iou: 0.8211 - dice_coef: 0.8992
# Epoch 00057: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.8989 - binary_accuracy: 0.9980 - iou: 0.8211 - dice_coef: 0.8992 - val_loss: -0.8995 - val_binary_accuracy: 0.9980 - val_iou: 0.8231 - val_dice_coef: 0.9019
# Epoch 58/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9011 - binary_accuracy: 0.9981 - iou: 0.8216 - dice_coef: 0.9007
# Epoch 00058: val_loss did not improve from -0.90178
# 89/88 [==============================] - 91s 1s/step - loss: -0.9011 - binary_accuracy: 0.9981 - iou: 0.8216 - dice_coef: 0.9007 - val_loss: -0.8849 - val_binary_accuracy: 0.9977 - val_iou: 0.7876 - val_dice_coef: 0.8773
# Epoch 59/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8964 - binary_accuracy: 0.9980 - iou: 0.8179 - dice_coef: 0.8965
# Epoch 00059: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.8964 - binary_accuracy: 0.9980 - iou: 0.8179 - dice_coef: 0.8965 - val_loss: -0.8907 - val_binary_accuracy: 0.9978 - val_iou: 0.7992 - val_dice_coef: 0.8869
# Epoch 60/100
# 89/88 [==============================] - ETA: 0s - loss: -0.0671 - binary_accuracy: 0.9345 - iou: 0.0356 - dice_coef: 0.0672
# Epoch 00060: val_loss did not improve from -0.90178
# 89/88 [==============================] - 89s 1s/step - loss: -0.0671 - binary_accuracy: 0.9345 - iou: 0.0356 - dice_coef: 0.0672 - val_loss: -0.4536 - val_binary_accuracy: 0.9726 - val_iou: 0.2907 - val_dice_coef: 0.4412
# Epoch 61/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8609 - binary_accuracy: 0.9961 - iou: 0.7725 - dice_coef: 0.8612
# Epoch 00061: val_loss did not improve from -0.90178
# 89/88 [==============================] - 89s 997ms/step - loss: -0.8609 - binary_accuracy: 0.9961 - iou: 0.7725 - dice_coef: 0.8612 - val_loss: -0.8867 - val_binary_accuracy: 0.9980 - val_iou: 0.8011 - val_dice_coef: 0.8879
# Epoch 62/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8856 - binary_accuracy: 0.9979 - iou: 0.8019 - dice_coef: 0.8859
# Epoch 00062: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.8856 - binary_accuracy: 0.9979 - iou: 0.8019 - dice_coef: 0.8859 - val_loss: -0.8623 - val_binary_accuracy: 0.9971 - val_iou: 0.7687 - val_dice_coef: 0.8637
# Epoch 63/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8891 - binary_accuracy: 0.9977 - iou: 0.8058 - dice_coef: 0.8876
# Epoch 00063: val_loss did not improve from -0.90178
# 89/88 [==============================] - 90s 1s/step - loss: -0.8891 - binary_accuracy: 0.9977 - iou: 0.8058 - dice_coef: 0.8876 - val_loss: -0.8888 - val_binary_accuracy: 0.9977 - val_iou: 0.7953 - val_dice_coef: 0.8782
# Epoch 64/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8971 - binary_accuracy: 0.9980 - iou: 0.8178 - dice_coef: 0.8968
# Epoch 00064: val_loss did not improve from -0.90178
# 89/88 [==============================] - 91s 1s/step - loss: -0.8971 - binary_accuracy: 0.9980 - iou: 0.8178 - dice_coef: 0.8968 - val_loss: -0.8987 - val_binary_accuracy: 0.9979 - val_iou: 0.8208 - val_dice_coef: 0.9006
# Epoch 65/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8913 - binary_accuracy: 0.9979 - iou: 0.8097 - dice_coef: 0.8916
# Epoch 00065: val_loss did not improve from -0.90178
# 89/88 [==============================] - 89s 1s/step - loss: -0.8913 - binary_accuracy: 0.9979 - iou: 0.8097 - dice_coef: 0.8916 - val_loss: -0.8927 - val_binary_accuracy: 0.9979 - val_iou: 0.8091 - val_dice_coef: 0.8919
# Epoch 66/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9012 - binary_accuracy: 0.9981 - iou: 0.8231 - dice_coef: 0.9016
# Epoch 00066: val_loss did not improve from -0.90178
# 89/88 [==============================] - 89s 1s/step - loss: -0.9012 - binary_accuracy: 0.9981 - iou: 0.8231 - dice_coef: 0.9016 - val_loss: -0.8943 - val_binary_accuracy: 0.9979 - val_iou: 0.8144 - val_dice_coef: 0.8948
# Epoch 67/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8979 - binary_accuracy: 0.9980 - iou: 0.8210 - dice_coef: 0.8978
# Epoch 00067: val_loss improved from -0.90178 to -0.90312, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 91s 1s/step - loss: -0.8979 - binary_accuracy: 0.9980 - iou: 0.8210 - dice_coef: 0.8978 - val_loss: -0.9031 - val_binary_accuracy: 0.9979 - val_iou: 0.8289 - val_dice_coef: 0.9042
# Epoch 68/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9000 - binary_accuracy: 0.9981 - iou: 0.8226 - dice_coef: 0.9002
# Epoch 00068: val_loss did not improve from -0.90312
# 89/88 [==============================] - 90s 1s/step - loss: -0.9000 - binary_accuracy: 0.9981 - iou: 0.8226 - dice_coef: 0.9002 - val_loss: -0.9008 - val_binary_accuracy: 0.9978 - val_iou: 0.8219 - val_dice_coef: 0.9015
# Epoch 69/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9035 - binary_accuracy: 0.9981 - iou: 0.8268 - dice_coef: 0.9034
# Epoch 00069: val_loss did not improve from -0.90312
# 89/88 [==============================] - 89s 1s/step - loss: -0.9035 - binary_accuracy: 0.9981 - iou: 0.8268 - dice_coef: 0.9034 - val_loss: -0.8968 - val_binary_accuracy: 0.9978 - val_iou: 0.8140 - val_dice_coef: 0.8965
# Epoch 70/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9040 - binary_accuracy: 0.9982 - iou: 0.8275 - dice_coef: 0.9042
# Epoch 00070: val_loss did not improve from -0.90312
# 89/88 [==============================] - 98s 1s/step - loss: -0.9040 - binary_accuracy: 0.9982 - iou: 0.8275 - dice_coef: 0.9042 - val_loss: -0.8993 - val_binary_accuracy: 0.9979 - val_iou: 0.8244 - val_dice_coef: 0.9007
# Epoch 71/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9075 - binary_accuracy: 0.9982 - iou: 0.8350 - dice_coef: 0.9077
# Epoch 00071: val_loss improved from -0.90312 to -0.90374, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 91s 1s/step - loss: -0.9075 - binary_accuracy: 0.9982 - iou: 0.8350 - dice_coef: 0.9077 - val_loss: -0.9037 - val_binary_accuracy: 0.9979 - val_iou: 0.8293 - val_dice_coef: 0.9059
# Epoch 72/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9022 - binary_accuracy: 0.9981 - iou: 0.8282 - dice_coef: 0.9024
# Epoch 00072: val_loss did not improve from -0.90374
# 89/88 [==============================] - 89s 1s/step - loss: -0.9022 - binary_accuracy: 0.9981 - iou: 0.8282 - dice_coef: 0.9024 - val_loss: -0.8959 - val_binary_accuracy: 0.9981 - val_iou: 0.8199 - val_dice_coef: 0.8983
# Epoch 73/100
# 89/88 [==============================] - ETA: 0s - loss: -0.0579 - binary_accuracy: 0.9510 - iou: 0.0313 - dice_coef: 0.0583
# Epoch 00073: val_loss did not improve from -0.90374
# 89/88 [==============================] - 90s 1s/step - loss: -0.0579 - binary_accuracy: 0.9510 - iou: 0.0313 - dice_coef: 0.0583 - val_loss: -0.5808 - val_binary_accuracy: 0.9854 - val_iou: 0.4021 - val_dice_coef: 0.5600
# Epoch 74/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8667 - binary_accuracy: 0.9964 - iou: 0.7799 - dice_coef: 0.8671
# Epoch 00074: val_loss did not improve from -0.90374
# 89/88 [==============================] - 89s 1s/step - loss: -0.8667 - binary_accuracy: 0.9964 - iou: 0.7799 - dice_coef: 0.8671 - val_loss: -0.8993 - val_binary_accuracy: 0.9977 - val_iou: 0.8230 - val_dice_coef: 0.9007
# Epoch 75/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8893 - binary_accuracy: 0.9980 - iou: 0.8072 - dice_coef: 0.8891
# Epoch 00075: val_loss did not improve from -0.90374
# 89/88 [==============================] - 89s 997ms/step - loss: -0.8893 - binary_accuracy: 0.9980 - iou: 0.8072 - dice_coef: 0.8891 - val_loss: -0.8457 - val_binary_accuracy: 0.9971 - val_iou: 0.7373 - val_dice_coef: 0.8457
# Epoch 76/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8969 - binary_accuracy: 0.9980 - iou: 0.8144 - dice_coef: 0.8940
# Epoch 00076: val_loss did not improve from -0.90374
# 89/88 [==============================] - 89s 998ms/step - loss: -0.8969 - binary_accuracy: 0.9980 - iou: 0.8144 - dice_coef: 0.8940 - val_loss: -0.8876 - val_binary_accuracy: 0.9977 - val_iou: 0.8035 - val_dice_coef: 0.8898
# Epoch 77/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8770 - binary_accuracy: 0.9976 - iou: 0.7861 - dice_coef: 0.8765
# Epoch 00077: val_loss did not improve from -0.90374
# 89/88 [==============================] - 90s 1s/step - loss: -0.8770 - binary_accuracy: 0.9976 - iou: 0.7861 - dice_coef: 0.8765 - val_loss: -0.8932 - val_binary_accuracy: 0.9977 - val_iou: 0.8073 - val_dice_coef: 0.8923
# Epoch 78/100
# 89/88 [==============================] - ETA: 0s - loss: -0.0407 - binary_accuracy: 0.9799 - iou: 0.0223 - dice_coef: 0.0405
# Epoch 00078: val_loss did not improve from -0.90374
# 89/88 [==============================] - 90s 1s/step - loss: -0.0407 - binary_accuracy: 0.9799 - iou: 0.0223 - dice_coef: 0.0405 - val_loss: -0.6361 - val_binary_accuracy: 0.9889 - val_iou: 0.4645 - val_dice_coef: 0.6151
# Epoch 79/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8790 - binary_accuracy: 0.9977 - iou: 0.7916 - dice_coef: 0.8793
# Epoch 00079: val_loss did not improve from -0.90374
# 89/88 [==============================] - 89s 995ms/step - loss: -0.8790 - binary_accuracy: 0.9977 - iou: 0.7916 - dice_coef: 0.8793 - val_loss: -0.8889 - val_binary_accuracy: 0.9980 - val_iou: 0.7780 - val_dice_coef: 0.8607
# Epoch 80/100
# 89/88 [==============================] - ETA: 0s - loss: -0.0494 - binary_accuracy: 0.9792 - iou: 0.0270 - dice_coef: 0.0491
# Epoch 00080: val_loss did not improve from -0.90374
# 89/88 [==============================] - 90s 1s/step - loss: -0.0494 - binary_accuracy: 0.9792 - iou: 0.0270 - dice_coef: 0.0491 - val_loss: -0.7052 - val_binary_accuracy: 0.9909 - val_iou: 0.5653 - val_dice_coef: 0.7144
# Epoch 81/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8733 - binary_accuracy: 0.9975 - iou: 0.7812 - dice_coef: 0.8728
# Epoch 00081: val_loss did not improve from -0.90374
# 89/88 [==============================] - 90s 1s/step - loss: -0.8733 - binary_accuracy: 0.9975 - iou: 0.7812 - dice_coef: 0.8728 - val_loss: -0.8694 - val_binary_accuracy: 0.9974 - val_iou: 0.7634 - val_dice_coef: 0.8627
# Epoch 82/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8861 - binary_accuracy: 0.9977 - iou: 0.8019 - dice_coef: 0.8866
# Epoch 00082: val_loss did not improve from -0.90374
# 89/88 [==============================] - 90s 1s/step - loss: -0.8861 - binary_accuracy: 0.9977 - iou: 0.8019 - dice_coef: 0.8866 - val_loss: -0.8966 - val_binary_accuracy: 0.9981 - val_iou: 0.8201 - val_dice_coef: 0.8990
# Epoch 83/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9000 - binary_accuracy: 0.9981 - iou: 0.8226 - dice_coef: 0.9004
# Epoch 00083: val_loss did not improve from -0.90374
# 89/88 [==============================] - 90s 1s/step - loss: -0.9000 - binary_accuracy: 0.9981 - iou: 0.8226 - dice_coef: 0.9004 - val_loss: -0.8754 - val_binary_accuracy: 0.9973 - val_iou: 0.7841 - val_dice_coef: 0.8773
# Epoch 84/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8996 - binary_accuracy: 0.9980 - iou: 0.8216 - dice_coef: 0.8993
# Epoch 00084: val_loss did not improve from -0.90374
# 89/88 [==============================] - 89s 1s/step - loss: -0.8996 - binary_accuracy: 0.9980 - iou: 0.8216 - dice_coef: 0.8993 - val_loss: -0.9020 - val_binary_accuracy: 0.9979 - val_iou: 0.8275 - val_dice_coef: 0.9045
# Epoch 85/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9046 - binary_accuracy: 0.9981 - iou: 0.8283 - dice_coef: 0.9002
# Epoch 00085: val_loss did not improve from -0.90374
# 89/88 [==============================] - 88s 986ms/step - loss: -0.9046 - binary_accuracy: 0.9981 - iou: 0.8283 - dice_coef: 0.9002 - val_loss: -0.9024 - val_binary_accuracy: 0.9978 - val_iou: 0.8269 - val_dice_coef: 0.9044
# Epoch 86/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9060 - binary_accuracy: 0.9981 - iou: 0.8345 - dice_coef: 0.9062
# Epoch 00086: val_loss improved from -0.90374 to -0.90718, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 88s 990ms/step - loss: -0.9060 - binary_accuracy: 0.9981 - iou: 0.8345 - dice_coef: 0.9062 - val_loss: -0.9072 - val_binary_accuracy: 0.9981 - val_iou: 0.8379 - val_dice_coef: 0.9096
# Epoch 87/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9024 - binary_accuracy: 0.9980 - iou: 0.8258 - dice_coef: 0.9018
# Epoch 00087: val_loss did not improve from -0.90718
# 89/88 [==============================] - 87s 983ms/step - loss: -0.9024 - binary_accuracy: 0.9980 - iou: 0.8258 - dice_coef: 0.9018 - val_loss: -0.9053 - val_binary_accuracy: 0.9979 - val_iou: 0.8343 - val_dice_coef: 0.9079
# Epoch 88/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9089 - binary_accuracy: 0.9982 - iou: 0.8351 - dice_coef: 0.9085
# Epoch 00088: val_loss did not improve from -0.90718
# 89/88 [==============================] - 90s 1s/step - loss: -0.9089 - binary_accuracy: 0.9982 - iou: 0.8351 - dice_coef: 0.9085 - val_loss: -0.8900 - val_binary_accuracy: 0.9976 - val_iou: 0.8065 - val_dice_coef: 0.8919
# Epoch 89/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8979 - binary_accuracy: 0.9980 - iou: 0.8231 - dice_coef: 0.8978
# Epoch 00089: val_loss did not improve from -0.90718
# 89/88 [==============================] - 90s 1s/step - loss: -0.8979 - binary_accuracy: 0.9980 - iou: 0.8231 - dice_coef: 0.8978 - val_loss: -0.8779 - val_binary_accuracy: 0.9977 - val_iou: 0.7889 - val_dice_coef: 0.8799
# Epoch 90/100
# 89/88 [==============================] - ETA: 0s - loss: -0.8796 - binary_accuracy: 0.9976 - iou: 0.7903 - dice_coef: 0.8799
# Epoch 00090: val_loss did not improve from -0.90718
# 89/88 [==============================] - 91s 1s/step - loss: -0.8796 - binary_accuracy: 0.9976 - iou: 0.7903 - dice_coef: 0.8799 - val_loss: -0.8997 - val_binary_accuracy: 0.9978 - val_iou: 0.8241 - val_dice_coef: 0.9024
# Epoch 91/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9064 - binary_accuracy: 0.9981 - iou: 0.8312 - dice_coef: 0.9058
# Epoch 00091: val_loss did not improve from -0.90718
# 89/88 [==============================] - 87s 982ms/step - loss: -0.9064 - binary_accuracy: 0.9981 - iou: 0.8312 - dice_coef: 0.9058 - val_loss: -0.9009 - val_binary_accuracy: 0.9980 - val_iou: 0.8157 - val_dice_coef: 0.8910
# Epoch 92/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9081 - binary_accuracy: 0.9982 - iou: 0.8339 - dice_coef: 0.9084
# Epoch 00092: val_loss did not improve from -0.90718
# 89/88 [==============================] - 90s 1s/step - loss: -0.9081 - binary_accuracy: 0.9982 - iou: 0.8339 - dice_coef: 0.9084 - val_loss: -0.8976 - val_binary_accuracy: 0.9979 - val_iou: 0.8043 - val_dice_coef: 0.8881
# Epoch 93/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9114 - binary_accuracy: 0.9982 - iou: 0.8389 - dice_coef: 0.9114
# Epoch 00093: val_loss did not improve from -0.90718
# 89/88 [==============================] - 88s 990ms/step - loss: -0.9114 - binary_accuracy: 0.9982 - iou: 0.8389 - dice_coef: 0.9114 - val_loss: -0.9064 - val_binary_accuracy: 0.9979 - val_iou: 0.8265 - val_dice_coef: 0.9040
# Epoch 94/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9096 - binary_accuracy: 0.9982 - iou: 0.8383 - dice_coef: 0.9099
# Epoch 00094: val_loss improved from -0.90718 to -0.90870, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 89s 996ms/step - loss: -0.9096 - binary_accuracy: 0.9982 - iou: 0.8383 - dice_coef: 0.9099 - val_loss: -0.9087 - val_binary_accuracy: 0.9981 - val_iou: 0.8344 - val_dice_coef: 0.9087
# Epoch 95/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9086 - binary_accuracy: 0.9982 - iou: 0.8377 - dice_coef: 0.9089
# Epoch 00095: val_loss improved from -0.90870 to -0.91157, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 89s 1s/step - loss: -0.9086 - binary_accuracy: 0.9982 - iou: 0.8377 - dice_coef: 0.9089 - val_loss: -0.9116 - val_binary_accuracy: 0.9982 - val_iou: 0.8381 - val_dice_coef: 0.9112
# Epoch 96/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9117 - binary_accuracy: 0.9983 - iou: 0.8404 - dice_coef: 0.9110
# Epoch 00096: val_loss did not improve from -0.91157
# 89/88 [==============================] - 88s 992ms/step - loss: -0.9117 - binary_accuracy: 0.9983 - iou: 0.8404 - dice_coef: 0.9110 - val_loss: -0.9046 - val_binary_accuracy: 0.9980 - val_iou: 0.8332 - val_dice_coef: 0.9075
# Epoch 97/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9123 - binary_accuracy: 0.9983 - iou: 0.8434 - dice_coef: 0.9125
# Epoch 00097: val_loss improved from -0.91157 to -0.91165, saving model to unet_brain_mri_seg.hdf5
# 89/88 [==============================] - 89s 999ms/step - loss: -0.9123 - binary_accuracy: 0.9983 - iou: 0.8434 - dice_coef: 0.9125 - val_loss: -0.9116 - val_binary_accuracy: 0.9981 - val_iou: 0.8410 - val_dice_coef: 0.9130
# Epoch 98/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9135 - binary_accuracy: 0.9982 - iou: 0.8451 - dice_coef: 0.9132
# Epoch 00098: val_loss did not improve from -0.91165
# 89/88 [==============================] - 90s 1s/step - loss: -0.9135 - binary_accuracy: 0.9982 - iou: 0.8451 - dice_coef: 0.9132 - val_loss: -0.9066 - val_binary_accuracy: 0.9980 - val_iou: 0.8249 - val_dice_coef: 0.9028
# Epoch 99/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9083 - binary_accuracy: 0.9982 - iou: 0.8375 - dice_coef: 0.9080
# Epoch 00099: val_loss did not improve from -0.91165
# 89/88 [==============================] - 88s 993ms/step - loss: -0.9083 - binary_accuracy: 0.9982 - iou: 0.8375 - dice_coef: 0.9080 - val_loss: -0.9080 - val_binary_accuracy: 0.9980 - val_iou: 0.8369 - val_dice_coef: 0.9101
# Epoch 100/100
# 89/88 [==============================] - ETA: 0s - loss: -0.9081 - binary_accuracy: 0.9983 - iou: 0.8343 - dice_coef: 0.9083
# Epoch 00100: val_loss did not improve from -0.91165
# 89/88 [==============================] - 92s 1s/step - loss: -0.9081 - binary_accuracy: 0.9983 - iou: 0.8343 - dice_coef: 0.9083 - val_loss: -0.9045 - val_binary_accuracy: 0.9980 - val_iou: 0.8272 - val_dice_coef: 0.9044

# %%
a = history.history

list_traindice = a['dice_coef']
list_testdice = a['val_dice_coef']

list_trainjaccard = a['iou']
list_testjaccard = a['val_iou']

list_trainloss = a['loss']
list_testloss = a['val_loss']
plt.figure(1)
plt.plot(list_testloss, 'b-')
plt.plot(list_trainloss,'r-')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('loss graph', fontsize = 15)
plt.figure(2)
plt.plot(list_traindice, 'r-')
plt.plot(list_testdice, 'b-')
plt.xlabel('iteration')
plt.ylabel('accuracy')
plt.title('accuracy graph', fontsize = 15)
plt.show()

# %%
model = load_model('unet_brain_mri_seg.hdf5', custom_objects={'dice_coef_loss': dice_coef_loss, 'iou': iou, 'dice_coef': dice_coef})

# %%
test_gen = train_generator(df_test, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
results = model.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)
print("Test lost: ",results[0])
print("Test IOU: ",results[1])
print("Test Dice Coefficent: ",results[2])
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 13/12 [===============================] - 3s 215ms/step - loss: -0.9168 - binary_accuracy: 0.9984 - iou: 0.8499 - dice_coef: 0.9182
# Test lost:  -0.9168355464935303
# Test IOU:  0.9983922839164734
# Test Dice Coefficent:  0.8499200344085693

# %%
for i in range(30):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['filename'].iloc[index])
    img = cv2.resize(img ,(im_height, im_width))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
