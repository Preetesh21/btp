# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Readin the metadata ffrom th csv file
df = pd.read_csv('../input/lgg-mri-segmentation/kaggle_3m/data.csv')
df.head()
# Out:
#         Patient  RNASeqCluster  MethylationCluster  miRNACluster  CNCluster  \
# 0  TCGA_CS_4941            2.0                 4.0             2        2.0
# 1  TCGA_CS_4942            1.0                 5.0             2        1.0
# 2  TCGA_CS_4943            1.0                 5.0             2        1.0
# 3  TCGA_CS_4944            NaN                 5.0             2        1.0
# 4  TCGA_CS_5393            4.0                 5.0             2        1.0
#
#    RPPACluster  OncosignCluster  COCCluster  histological_type  \
# 0          NaN              3.0           2                1.0
# 1          1.0              2.0           1                1.0
# 2          2.0              2.0           1                1.0
# 3          2.0              1.0           1                1.0
# 4          2.0              3.0           1                1.0
#
#    neoplasm_histologic_grade  tumor_tissue_site  laterality  tumor_location  \
# 0                        2.0                1.0         3.0             2.0
# 1                        2.0                1.0         3.0             2.0
# 2                        2.0                1.0         1.0             2.0
# 3                        1.0                1.0         3.0             6.0
# 4                        2.0                1.0         1.0             6.0
#
#    gender  age_at_initial_pathologic  race  ethnicity  death01
# 0     2.0                       67.0   3.0        2.0      1.0
# 1     1.0                       44.0   2.0        NaN      1.0
# 2     2.0                       37.0   3.0        NaN      0.0
# 3     2.0                       50.0   3.0        NaN      0.0
# 4     2.0                       39.0   3.0        NaN      0.0

# %%
# Printing the Metadata details
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient                    110 non-null    object
#  1   RNASeqCluster              92 non-null     float64
#  2   MethylationCluster         109 non-null    float64
#  3   miRNACluster               110 non-null    int64
#  4   CNCluster                  108 non-null    float64
#  5   RPPACluster                98 non-null     float64
#  6   OncosignCluster            105 non-null    float64
#  7   COCCluster                 110 non-null    int64
#  8   histological_type          109 non-null    float64
#  9   neoplasm_histologic_grade  109 non-null    float64
#  10  tumor_tissue_site          109 non-null    float64
#  11  laterality                 109 non-null    float64
#  12  tumor_location             109 non-null    float64
#  13  gender                     109 non-null    float64
#  14  age_at_initial_pathologic  109 non-null    float64
#  15  race                       108 non-null    float64
#  16  ethnicity                  102 non-null    float64
#  17  death01                    109 non-null    float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 15.6+ KB

# %%
df.shape
# Out:
# (110, 18)

# %%
import glob 
data_map = []
for directory in glob.glob("../input/lgg-mri-segmentation/kaggle_3m/*"):
# directory here will return the 110 folders we are navigating 
# For example : Directory :  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307
    try:
        dir_name = directory.split("/")[-1]
        # dir_name extracts the folder name from the directory. For the above example would return TCGA_DU_7010_19860307
        # print("Directory : ", directory , " Dir_name : ", dir_name)
        # For every file in the directory(we have 110 directories) we form the "absolute file path"
        # for the actual RGB image and the mask image.
        # Example for filename : CGA_DU_7010_19860307_56_mask.tif  and TCGA_DU_7010_19860307_56.tif
        # image path with be concatenation of directory and filename
        # Example :  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56_mask.tif 
        # Example : ../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56.tif
        for filename in os.listdir(directory):
            image_path = directory + '/' + filename
            # data_map is one-to-one mapping of Directory name and the absolute file path of an RGB or mask file 
            data_map.extend([dir_name, image_path])
    except Exception as e:
        print(e)
# Out:
# [Errno 20] Not a directory: '../input/lgg-mri-segmentation/kaggle_3m/README.md'
# [Errno 20] Not a directory: '../input/lgg-mri-segmentation/kaggle_3m/data.csv'

# %%
data_map[:5]
# Out:
# ['TCGA_DU_7010_19860307',
#  '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_45.tif',
#  'TCGA_DU_7010_19860307',
#  '../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_56_mask.tif',
#  'TCGA_DU_7010_19860307']

# %%
new_df = pd.DataFrame({"patient_id" : data_map[::2],
                   "path" : data_map[1::2]})
new_df.head()
# Out:
#               patient_id                                               path
# 0  TCGA_DU_7010_19860307  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 1  TCGA_DU_7010_19860307  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 2  TCGA_DU_7010_19860307  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 3  TCGA_DU_7010_19860307  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 4  TCGA_DU_7010_19860307  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...

# %%
# More about str.contains in a Pandas Series can be found here : https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html
normal_images = new_df[~new_df['path'].str.contains("mask")]
mask_images = new_df[new_df['path'].str.contains("mask")]

# %%
# Sorting the Images and mask so as to form one-to-one correspondence
common_file_length = 84
# Any file with its absolute file path has minimum characters in the file name
# For example : ../input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7010_19860307/TCGA_DU_7010_19860307_   has 84 characters

normal_img_file_length = 4
# Normal file has only .tif common at its end, hence the value(len(.tif)) equal to 4

mask_img_file_length = 9
# mask files has _mask.tif at their end making its length(len(_mask.tif)) equal to 9

# Data sorting
imgs = sorted(normal_images["path"].values, key=lambda x : int(x[common_file_length:-normal_img_file_length]))
masks = sorted(mask_images["path"].values, key=lambda x :  int(x[common_file_length:-mask_img_file_length]))

# x[common_file_length:-normal_img_file_length] is picking up the number stored after "TCGA_DU_7010_19860307_" and before ".tif" from a given Image x
# Same is happening w.r.t Mask Image

# Sorting check
idx = random.randint(0, len(imgs)-1)
print("Path to the Image:", imgs[idx])
print("\nPath to the Mask:", masks[idx])
# Out:
# Path to the Image: ../input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_7634_20000128/TCGA_FG_7634_20000128_27.tif
#
# Path to the Mask: ../input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_7634_20000128/TCGA_FG_7634_20000128_27_mask.tif

# %%
#Lets plot some samples
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=imgs[i]
    msk_path=masks[i]
    img=cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %%
# Now we need to create a DataFrame contains 4 columns
# 1. Patient ID
# 2. An RGB Image
# 3. It;s corresponding Mask Image
# 4. Mask Binary value : 0 and 1 depending on the image of the mask

import cv2

# Final dataframe
final_df = pd.DataFrame({"patient_id": normal_images.patient_id.values,
                         "image_path": imgs,
                         "mask_path": masks
                        })

# Creating the 3td column for our final df where if the entire mask image is black(0 i.e no tumor) then its value will be 0 else 1
# def pos_neg_diagnosis(mask_path):
#     value = np.max(cv2.imread(mask_path)) # Checking for the maximum pixel value in the mask image
#     if value > 0 :  # Non zero value then tumor is present in the mask image
#         return 1
#     else:           # Zero value means no tumor
#         return 0
    
# final_df['mask'] = final_df['mask_path'].apply(lambda x: pos_neg_diagnosis(x))
# final_df

# %%
def diagnosis(mask_path):
    value = np.max(cv2.imread(mask_path))
    return '1' if value > 0 else '0'
df = pd.DataFrame({"image_path": imgs,
                   "mask_path": masks,
                  "diagnosis":[diagnosis(x) for x in masks]})
df.head()
# Plot
ax = df.diagnosis.value_counts().plot(kind='bar',
                                      stacked=True,
                                      figsize=(10, 6),
                                     color=["violet", "lightseagreen"])


ax.set_xticklabels(["Positive", "Negative"], rotation=45, fontsize=12);
ax.set_ylabel('Total Images', fontsize = 12)
ax.set_title("Distribution of data grouped by diagnosis",fontsize = 18, y=1.05)

# Annotate
for i, rows in enumerate(df.diagnosis.value_counts().values):
    ax.annotate(int(rows), xy=(i, rows-12), 
                rotation=0, color="white", 
                ha="center", verticalalignment='bottom', 
                fontsize=15, fontweight="bold")
    
ax.text(1.2, 2550, f"Total {len(df)} images", size=15,
        color="black",
         ha="center", va="center",
         bbox=dict(boxstyle="round",
                   fc=("lightblue"),
                   ec=("black"),
                   )
         );

# %%
from sklearn.model_selection import train_test_split
X_train,X_val = train_test_split(final_df,test_size = 0.1)
X_val,X_test = train_test_split(X_val,test_size = 0.2)
print("X_train Shape : ", X_train.shape)
print("X_val Shape : ", X_val.shape)
print("X_test Shape : ", X_test.shape)
# Out:
# X_train Shape :  (3143, 3)
# X_val Shape :  (393, 3)
# X_test Shape :  (393, 3)

# %%
# Data creation so as to pass to Custom Data Generators
X_train_img = list(X_train.image_path)
X_train_mask = list(X_train.mask_path)

X_val_img = list(X_val.image_path)
X_val_mask = list(X_val.mask_path)

# %%
from skimage import io
import cv2
import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.python.keras.utils.data_utils import Sequence

# %%
def train_generator(data_frame,batch_size,aug_dict,
                   image_color_mode = "rgb",
                   mask_color_mode = "grayscale",
                   image_save_prefix = "image_path",
                   mask_save_prefix = "mask_path",
                   save_to_dir = None,
                   target_size = (256,256),
                   seed = 1):
    
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    
    image_datagenerator = image_datagen.flow_from_dataframe(
         data_frame,
         x_col = "image_path",
         class_mode = None,
         color_mode = image_color_mode,
         target_size = target_size,
         batch_size = batch_size,
         save_to_dir = save_to_dir,
         save_prefix = image_save_prefix,
         seed = seed)
    
    mask_datagenerator = mask_datagen.flow_from_dataframe(
         data_frame,
         x_col = "mask_path",
         class_mode = None,
         color_mode = mask_color_mode,
         target_size = target_size,
         batch_size = batch_size,
         save_to_dir = save_to_dir,
         save_prefix = mask_save_prefix,
         seed = seed)
    
    train_gen = zip(image_datagenerator,mask_datagenerator)
    
    for (img,mask) in train_gen:
        img,mask = adjust_data(img,mask)
        yield (img,mask)


def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    return (img,mask)

# %%
# loss function and metrics
# Reference : https://towardsdatascience.com/metrics-to-evaluate-your-semantic-segmentation-model-6bcb99639aa2
#             https://www.kaggle.com/masoumehavahedi/brain-mri-attention-segmentation?scriptVersionId=68934190&cellId=21
def dice_coef(y_pred, Y):
    y_flatten = K.flatten(Y)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_flatten * y_pred_flatten)
    union = K.sum(y_flatten) + K.sum(y_pred_flatten)
    dice = (2.0 * intersection + 1.0) / (union + 1.0)
    return dice

def jacard_coef(y_pred, Y,smooth = 1.0):
    y_flatten = K.flatten(Y)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_flatten * y_pred_flatten)
    union = K.sum(y_flatten) + K.sum(y_pred_flatten)
    jacard = (intersection + smooth) / (union - intersection + smooth)
    return jacard

def jacard_coef_loss(y_pred, Y):
    return -jacard_coef(y_pred, Y)


def dice_coef_loss(y_pred, Y):
    return -dice_coef(y_pred, Y)

# %%
from tensorflow.keras.layers import *

def batchnorm_relu(inputs):
    "Adding Batch Normalization and Relu"
    x = BatchNormalization()(inputs)
    x = Activation("relu")(x)
    
    return x

def residual_block(inputs,num_filters = 16,strides = 1):
    X = batchnorm_relu(inputs)
    X = Conv2D(num_filters,(3,3), padding = "same", strides = strides,kernel_initializer='he_normal')(X)
    X = batchnorm_relu(X)
    X = Conv2D(num_filters,(3,3), padding = "same", strides = 1,kernel_initializer='he_normal')(X)
    
    # Adding Shortcut Conection for Addition
    X_add = Conv2D(num_filters,(1,1), padding = "same", strides = strides,kernel_initializer='he_normal')(inputs)
    
    X = Add()([X, X_add])
    
    return X

def decoder_block(inputs,skip_features,num_filters = 16):
    X = UpSampling2D((2, 2))(inputs)
    X = Concatenate()([X, skip_features])
    X = residual_block(X,num_filters,strides = 1)
    
    return X

# %%
def ResUnet():
    input_img = Input((256, 256, 3), name='img')
    
    # Encoder part
    X = Conv2D(16,(3,3),padding = "same",kernel_initializer='he_normal',strides = 1)(input_img)
    X = batchnorm_relu(X)
    X = Conv2D(32,(3,3),padding = "same",kernel_initializer='he_normal',strides = 1)(X)
    X_add = Conv2D(32,(1,1),padding = "same",kernel_initializer='he_normal',strides = 1)(input_img)
    
    s1 = Add()([X, X_add])
    
    s2 = residual_block(s1,64,strides = 2)
    s2 = Dropout(0.2)(s2)
    s3 = residual_block(s2,128,strides = 2)
    
    bridge = residual_block(s3,256,strides = 2)
    
    d1 = decoder_block(bridge,s3,128)
    d1 = Dropout(0.2)(d1)
    d2 = decoder_block(d1,s2,64)
    d3 = decoder_block(d2,s1,32)
    
    outputs = Conv2D(1,(1,1), padding = "same",activation = "sigmoid")(d3)
    
    resunet = Model(inputs = [input_img], outputs = outputs)
    
    return resunet

# %%
res_unet_model = ResUnet()
res_unet_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 16) 448         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 32) 4640        activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 32) 128         img[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256, 256, 32) 0           conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 32) 128         add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 18496       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 64) 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 64) 2112        add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 64) 0           conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 64) 0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 64) 256         dropout[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 128)  73856       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 128)  147584      activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 128)  8320        dropout[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 128)  0           conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 128)  512         add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 256)  295168      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 256)  33024       add_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 256)  0           conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 64, 64, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 384)  0           up_sampling2d[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 384)  1536        concatenate[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 384)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 128)  442496      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  147584      activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 128)  49280       concatenate[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 128)  0           conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 128 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 192 0           up_sampling2d_1[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 192 768         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 128, 128, 192 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 64) 110656      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 128, 64) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 64) 36928       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 64) 12352       concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 128, 128, 64) 0           conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 64) 0           add_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 96) 0           up_sampling2d_2[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 256, 256, 96) 384         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 256, 256, 96) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 32) 27680       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 256, 256, 32) 128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 256, 256, 32) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 32) 9248        activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 32) 3104        concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256, 256, 32) 0           conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 1)  33          add_6[0][0]
# ==================================================================================================
# Total params: 2,056,481
# Trainable params: 2,053,313
# Non-trainable params: 3,168
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(res_unet_model, to_file="resunet.png", show_shapes=True)

# %%
# compling model and callbacks functions

# adam = tf.keras.optimizers.Adam(0.0001)

BATCH_SIZE = 32
learning_rate = 1e-4

train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

train_gen = train_generator(X_train,BATCH_SIZE,
                           train_generator_args,
                           target_size = (256,256))

validation_gen = train_generator(X_val,BATCH_SIZE,
                           dict(),
                           target_size = (256,256))

optimizer = tf.keras.optimizers.Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, amsgrad=False)

res_unet_model.compile(optimizer = "adam", loss = dice_coef_loss, metrics = ["binary_accuracy", jacard_coef, dice_coef])
# model.compile(optimizer = optimizer, loss = "binary_crossentropy", metrics = ["accuracy"])

earlystopping = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=10)

# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath="ResUNet-segModel-weights.hdf5",verbose=1,save_best_only=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',mode='min',verbose=1,patience=10,min_delta=0.0001,factor=0.1)

# %%
tf.keras.backend.clear_session()
history = res_unet_model.fit(train_gen, steps_per_epoch=len(X_train) / BATCH_SIZE, epochs = 100, validation_data = validation_gen,
                    validation_steps=len(X_val) / BATCH_SIZE,
                    callbacks = [earlystopping,checkpointer,reduce_lr])
# Out:
# Found 3143 validated image filenames.
# Found 3143 validated image filenames.
# Epoch 1/100
# 99/98 [==============================] - ETA: 0s - loss: -0.3347 - binary_accuracy: 0.9113 - jacard_coef: 0.2192 - dice_coef: 0.3347Found 393 validated image filenames.
# Found 393 validated image filenames.
# 98/98 [==============================] - 120s 1s/step - loss: -0.3359 - binary_accuracy: 0.9119 - jacard_coef: 0.2201 - dice_coef: 0.3359 - val_loss: -0.0718 - val_binary_accuracy: 0.9905 - val_jacard_coef: 0.0548 - val_dice_coef: 0.0932
#
# Epoch 00001: val_loss improved from inf to -0.07183, saving model to ResUNet-segModel-weights.hdf5
# Epoch 2/100
# 98/98 [==============================] - 83s 852ms/step - loss: -0.5456 - binary_accuracy: 0.9914 - jacard_coef: 0.3863 - dice_coef: 0.5455 - val_loss: -0.2675 - val_binary_accuracy: 0.9901 - val_jacard_coef: 0.1591 - val_dice_coef: 0.2544
#
# Epoch 00002: val_loss improved from -0.07183 to -0.26750, saving model to ResUNet-segModel-weights.hdf5
# Epoch 3/100
# 98/98 [==============================] - 85s 873ms/step - loss: -0.5974 - binary_accuracy: 0.9916 - jacard_coef: 0.4364 - dice_coef: 0.5974 - val_loss: -0.4431 - val_binary_accuracy: 0.9914 - val_jacard_coef: 0.2922 - val_dice_coef: 0.4455
#
# Epoch 00003: val_loss improved from -0.26750 to -0.44309, saving model to ResUNet-segModel-weights.hdf5
# Epoch 4/100
# 98/98 [==============================] - 86s 878ms/step - loss: -0.5820 - binary_accuracy: 0.9919 - jacard_coef: 0.4240 - dice_coef: 0.5820 - val_loss: -0.5561 - val_binary_accuracy: 0.9936 - val_jacard_coef: 0.3838 - val_dice_coef: 0.5446
#
# Epoch 00004: val_loss improved from -0.44309 to -0.55611, saving model to ResUNet-segModel-weights.hdf5
# Epoch 5/100
# 98/98 [==============================] - 86s 882ms/step - loss: -0.5956 - binary_accuracy: 0.9927 - jacard_coef: 0.4378 - dice_coef: 0.5956 - val_loss: -0.6162 - val_binary_accuracy: 0.9925 - val_jacard_coef: 0.4643 - val_dice_coef: 0.6250
#
# Epoch 00005: val_loss improved from -0.55611 to -0.61622, saving model to ResUNet-segModel-weights.hdf5
# Epoch 6/100
# 98/98 [==============================] - 85s 871ms/step - loss: -0.6611 - binary_accuracy: 0.9935 - jacard_coef: 0.5045 - dice_coef: 0.6610 - val_loss: -0.6028 - val_binary_accuracy: 0.9946 - val_jacard_coef: 0.4334 - val_dice_coef: 0.5890
#
# Epoch 00006: val_loss did not improve from -0.61622
# Epoch 7/100
# 98/98 [==============================] - 84s 856ms/step - loss: -0.6582 - binary_accuracy: 0.9934 - jacard_coef: 0.4998 - dice_coef: 0.6582 - val_loss: -0.6889 - val_binary_accuracy: 0.9937 - val_jacard_coef: 0.5465 - val_dice_coef: 0.6995
#
# Epoch 00007: val_loss improved from -0.61622 to -0.68891, saving model to ResUNet-segModel-weights.hdf5
# Epoch 8/100
# 98/98 [==============================] - 82s 843ms/step - loss: -0.6238 - binary_accuracy: 0.9923 - jacard_coef: 0.4710 - dice_coef: 0.6238 - val_loss: -0.6660 - val_binary_accuracy: 0.9953 - val_jacard_coef: 0.5135 - val_dice_coef: 0.6659
#
# Epoch 00008: val_loss did not improve from -0.68891
# Epoch 9/100
# 98/98 [==============================] - 81s 827ms/step - loss: -0.6671 - binary_accuracy: 0.9941 - jacard_coef: 0.5100 - dice_coef: 0.6671 - val_loss: -0.7124 - val_binary_accuracy: 0.9946 - val_jacard_coef: 0.5462 - val_dice_coef: 0.7030
#
# Epoch 00009: val_loss improved from -0.68891 to -0.71240, saving model to ResUNet-segModel-weights.hdf5
# Epoch 10/100
# 98/98 [==============================] - 80s 821ms/step - loss: -0.7043 - binary_accuracy: 0.9944 - jacard_coef: 0.5544 - dice_coef: 0.7043 - val_loss: -0.7082 - val_binary_accuracy: 0.9956 - val_jacard_coef: 0.5651 - val_dice_coef: 0.7151
#
# Epoch 00010: val_loss did not improve from -0.71240
# Epoch 11/100
# 98/98 [==============================] - 81s 832ms/step - loss: -0.6904 - binary_accuracy: 0.9942 - jacard_coef: 0.5461 - dice_coef: 0.6904 - val_loss: -0.7447 - val_binary_accuracy: 0.9956 - val_jacard_coef: 0.5834 - val_dice_coef: 0.7329
#
# Epoch 00011: val_loss improved from -0.71240 to -0.74472, saving model to ResUNet-segModel-weights.hdf5
# Epoch 12/100
# 98/98 [==============================] - 80s 822ms/step - loss: -0.6947 - binary_accuracy: 0.9940 - jacard_coef: 0.5484 - dice_coef: 0.6946 - val_loss: -0.6988 - val_binary_accuracy: 0.9955 - val_jacard_coef: 0.5311 - val_dice_coef: 0.6914
#
# Epoch 00012: val_loss did not improve from -0.74472
# Epoch 13/100
# 98/98 [==============================] - 82s 834ms/step - loss: -0.0591 - binary_accuracy: 0.8961 - jacard_coef: 0.0307 - dice_coef: 0.0591 - val_loss: -0.4376 - val_binary_accuracy: 0.9910 - val_jacard_coef: 0.2910 - val_dice_coef: 0.4433
#
# Epoch 00013: val_loss did not improve from -0.74472
# Epoch 14/100
# 98/98 [==============================] - 80s 813ms/step - loss: -0.5469 - binary_accuracy: 0.9825 - jacard_coef: 0.3988 - dice_coef: 0.5469 - val_loss: -0.5996 - val_binary_accuracy: 0.9922 - val_jacard_coef: 0.4186 - val_dice_coef: 0.5791
#
# Epoch 00014: val_loss did not improve from -0.74472
# Epoch 15/100
# 98/98 [==============================] - 83s 854ms/step - loss: -0.7121 - binary_accuracy: 0.9944 - jacard_coef: 0.5642 - dice_coef: 0.7122 - val_loss: -0.7128 - val_binary_accuracy: 0.9954 - val_jacard_coef: 0.5751 - val_dice_coef: 0.7227
#
# Epoch 00015: val_loss did not improve from -0.74472
# Epoch 16/100
# 98/98 [==============================] - 82s 837ms/step - loss: -0.7199 - binary_accuracy: 0.9943 - jacard_coef: 0.5745 - dice_coef: 0.7199 - val_loss: -0.7138 - val_binary_accuracy: 0.9951 - val_jacard_coef: 0.5487 - val_dice_coef: 0.7028
#
# Epoch 00016: val_loss did not improve from -0.74472
# Epoch 17/100
# 98/98 [==============================] - 83s 845ms/step - loss: -0.7183 - binary_accuracy: 0.9946 - jacard_coef: 0.5717 - dice_coef: 0.7183 - val_loss: -0.7100 - val_binary_accuracy: 0.9950 - val_jacard_coef: 0.5751 - val_dice_coef: 0.7227
#
# Epoch 00017: val_loss did not improve from -0.74472
# Epoch 18/100
# 98/98 [==============================] - 81s 828ms/step - loss: -0.7194 - binary_accuracy: 0.9950 - jacard_coef: 0.5794 - dice_coef: 0.7193 - val_loss: -0.6934 - val_binary_accuracy: 0.9960 - val_jacard_coef: 0.5127 - val_dice_coef: 0.6552
#
# Epoch 00018: val_loss did not improve from -0.74472
# Epoch 19/100
# 98/98 [==============================] - 81s 832ms/step - loss: -0.7336 - binary_accuracy: 0.9949 - jacard_coef: 0.5936 - dice_coef: 0.7336 - val_loss: -0.6956 - val_binary_accuracy: 0.9954 - val_jacard_coef: 0.5325 - val_dice_coef: 0.6864
#
# Epoch 00019: val_loss did not improve from -0.74472
# Epoch 20/100
# 98/98 [==============================] - 82s 835ms/step - loss: -0.7338 - binary_accuracy: 0.9949 - jacard_coef: 0.5920 - dice_coef: 0.7338 - val_loss: -0.7451 - val_binary_accuracy: 0.9963 - val_jacard_coef: 0.6022 - val_dice_coef: 0.7479
#
# Epoch 00020: val_loss improved from -0.74472 to -0.74505, saving model to ResUNet-segModel-weights.hdf5
# Epoch 21/100
# 98/98 [==============================] - 82s 837ms/step - loss: -0.7661 - binary_accuracy: 0.9952 - jacard_coef: 0.6260 - dice_coef: 0.7661 - val_loss: -0.7342 - val_binary_accuracy: 0.9948 - val_jacard_coef: 0.5800 - val_dice_coef: 0.7294
#
# Epoch 00021: val_loss did not improve from -0.74505
# Epoch 22/100
# 98/98 [==============================] - 80s 823ms/step - loss: -0.7389 - binary_accuracy: 0.9949 - jacard_coef: 0.5986 - dice_coef: 0.7390 - val_loss: -0.7366 - val_binary_accuracy: 0.9963 - val_jacard_coef: 0.5919 - val_dice_coef: 0.7414
#
# Epoch 00022: val_loss did not improve from -0.74505
# Epoch 23/100
# 98/98 [==============================] - 80s 815ms/step - loss: -0.7587 - binary_accuracy: 0.9954 - jacard_coef: 0.6227 - dice_coef: 0.7587 - val_loss: -0.7147 - val_binary_accuracy: 0.9956 - val_jacard_coef: 0.5753 - val_dice_coef: 0.7233
#
# Epoch 00023: val_loss did not improve from -0.74505
# Epoch 24/100
# 98/98 [==============================] - 80s 820ms/step - loss: -0.7788 - binary_accuracy: 0.9959 - jacard_coef: 0.6537 - dice_coef: 0.7788 - val_loss: -0.5992 - val_binary_accuracy: 0.9919 - val_jacard_coef: 0.4432 - val_dice_coef: 0.6085
#
# Epoch 00024: val_loss did not improve from -0.74505
# Epoch 25/100
# 98/98 [==============================] - 79s 811ms/step - loss: -0.7686 - binary_accuracy: 0.9954 - jacard_coef: 0.6372 - dice_coef: 0.7686 - val_loss: -0.7320 - val_binary_accuracy: 0.9960 - val_jacard_coef: 0.6017 - val_dice_coef: 0.7438
#
# Epoch 00025: val_loss did not improve from -0.74505
# Epoch 26/100
# 98/98 [==============================] - 80s 820ms/step - loss: -0.7795 - binary_accuracy: 0.9955 - jacard_coef: 0.6498 - dice_coef: 0.7795 - val_loss: -0.7190 - val_binary_accuracy: 0.9958 - val_jacard_coef: 0.5931 - val_dice_coef: 0.7346
#
# Epoch 00026: val_loss did not improve from -0.74505
# Epoch 27/100
# 98/98 [==============================] - 80s 819ms/step - loss: -0.7741 - binary_accuracy: 0.9955 - jacard_coef: 0.6468 - dice_coef: 0.7741 - val_loss: -0.7695 - val_binary_accuracy: 0.9959 - val_jacard_coef: 0.6142 - val_dice_coef: 0.7560
#
# Epoch 00027: val_loss improved from -0.74505 to -0.76947, saving model to ResUNet-segModel-weights.hdf5
# Epoch 28/100
# 98/98 [==============================] - 81s 827ms/step - loss: -0.7757 - binary_accuracy: 0.9955 - jacard_coef: 0.6445 - dice_coef: 0.7758 - val_loss: -0.7733 - val_binary_accuracy: 0.9963 - val_jacard_coef: 0.6475 - val_dice_coef: 0.7821
#
# Epoch 00028: val_loss improved from -0.76947 to -0.77333, saving model to ResUNet-segModel-weights.hdf5
# Epoch 29/100
# 98/98 [==============================] - 81s 828ms/step - loss: -0.8050 - binary_accuracy: 0.9962 - jacard_coef: 0.6809 - dice_coef: 0.8050 - val_loss: -0.7446 - val_binary_accuracy: 0.9957 - val_jacard_coef: 0.6062 - val_dice_coef: 0.7517
#
# Epoch 00029: val_loss did not improve from -0.77333
# Epoch 30/100
# 98/98 [==============================] - 80s 823ms/step - loss: -0.8002 - binary_accuracy: 0.9957 - jacard_coef: 0.6810 - dice_coef: 0.8002 - val_loss: -0.7571 - val_binary_accuracy: 0.9968 - val_jacard_coef: 0.5956 - val_dice_coef: 0.7248
#
# Epoch 00030: val_loss did not improve from -0.77333
# Epoch 31/100
# 98/98 [==============================] - 81s 826ms/step - loss: -0.8063 - binary_accuracy: 0.9960 - jacard_coef: 0.6845 - dice_coef: 0.8062 - val_loss: -0.7784 - val_binary_accuracy: 0.9962 - val_jacard_coef: 0.6473 - val_dice_coef: 0.7838
#
# Epoch 00031: val_loss improved from -0.77333 to -0.77836, saving model to ResUNet-segModel-weights.hdf5
# Epoch 32/100
# 98/98 [==============================] - 79s 812ms/step - loss: -0.8167 - binary_accuracy: 0.9959 - jacard_coef: 0.6988 - dice_coef: 0.8167 - val_loss: -0.7519 - val_binary_accuracy: 0.9967 - val_jacard_coef: 0.6191 - val_dice_coef: 0.7609
#
# Epoch 00032: val_loss did not improve from -0.77836
# Epoch 33/100
# 98/98 [==============================] - 80s 815ms/step - loss: -0.7576 - binary_accuracy: 0.9954 - jacard_coef: 0.6242 - dice_coef: 0.7577 - val_loss: -0.8030 - val_binary_accuracy: 0.9966 - val_jacard_coef: 0.6769 - val_dice_coef: 0.8060
#
# Epoch 00033: val_loss improved from -0.77836 to -0.80302, saving model to ResUNet-segModel-weights.hdf5
# Epoch 34/100
# 98/98 [==============================] - 80s 815ms/step - loss: -0.7961 - binary_accuracy: 0.9962 - jacard_coef: 0.6789 - dice_coef: 0.7961 - val_loss: -0.7875 - val_binary_accuracy: 0.9966 - val_jacard_coef: 0.6386 - val_dice_coef: 0.7699
#
# Epoch 00034: val_loss did not improve from -0.80302
# Epoch 35/100
# 98/98 [==============================] - 81s 831ms/step - loss: -0.7930 - binary_accuracy: 0.9964 - jacard_coef: 0.6710 - dice_coef: 0.7930 - val_loss: -0.6847 - val_binary_accuracy: 0.9954 - val_jacard_coef: 0.5051 - val_dice_coef: 0.6469
#
# Epoch 00035: val_loss did not improve from -0.80302
# Epoch 36/100
# 98/98 [==============================] - 80s 817ms/step - loss: -0.8117 - binary_accuracy: 0.9961 - jacard_coef: 0.6920 - dice_coef: 0.8116 - val_loss: -0.8138 - val_binary_accuracy: 0.9968 - val_jacard_coef: 0.6961 - val_dice_coef: 0.8191
#
# Epoch 00036: val_loss improved from -0.80302 to -0.81384, saving model to ResUNet-segModel-weights.hdf5
# Epoch 37/100
# 98/98 [==============================] - 80s 816ms/step - loss: -0.8084 - binary_accuracy: 0.9963 - jacard_coef: 0.6934 - dice_coef: 0.8083 - val_loss: -0.7238 - val_binary_accuracy: 0.9960 - val_jacard_coef: 0.5820 - val_dice_coef: 0.7245
#
# Epoch 00037: val_loss did not improve from -0.81384
# Epoch 38/100
# 98/98 [==============================] - 81s 829ms/step - loss: -0.0458 - binary_accuracy: 0.9375 - jacard_coef: 0.0237 - dice_coef: 0.0458 - val_loss: -0.1003 - val_binary_accuracy: 0.9898 - val_jacard_coef: 0.0514 - val_dice_coef: 0.0951
#
# Epoch 00038: val_loss did not improve from -0.81384
# Epoch 39/100
# 98/98 [==============================] - 81s 830ms/step - loss: -0.6242 - binary_accuracy: 0.9766 - jacard_coef: 0.5017 - dice_coef: 0.6242 - val_loss: -0.7626 - val_binary_accuracy: 0.9961 - val_jacard_coef: 0.6200 - val_dice_coef: 0.7575
#
# Epoch 00039: val_loss did not improve from -0.81384
# Epoch 40/100
# 98/98 [==============================] - 81s 826ms/step - loss: -0.7766 - binary_accuracy: 0.9959 - jacard_coef: 0.6513 - dice_coef: 0.7766 - val_loss: -0.7672 - val_binary_accuracy: 0.9965 - val_jacard_coef: 0.6373 - val_dice_coef: 0.7723
#
# Epoch 00040: val_loss did not improve from -0.81384
# Epoch 41/100
# 98/98 [==============================] - 80s 814ms/step - loss: -0.8185 - binary_accuracy: 0.9964 - jacard_coef: 0.7070 - dice_coef: 0.8185 - val_loss: -0.8213 - val_binary_accuracy: 0.9969 - val_jacard_coef: 0.7107 - val_dice_coef: 0.8262
#
# Epoch 00041: val_loss improved from -0.81384 to -0.82127, saving model to ResUNet-segModel-weights.hdf5
# Epoch 42/100
# 98/98 [==============================] - 80s 822ms/step - loss: -0.8388 - binary_accuracy: 0.9970 - jacard_coef: 0.7284 - dice_coef: 0.8388 - val_loss: -0.8273 - val_binary_accuracy: 0.9972 - val_jacard_coef: 0.6889 - val_dice_coef: 0.8105
#
# Epoch 00042: val_loss improved from -0.82127 to -0.82733, saving model to ResUNet-segModel-weights.hdf5
# Epoch 43/100
# 98/98 [==============================] - 80s 817ms/step - loss: -0.8225 - binary_accuracy: 0.9967 - jacard_coef: 0.7108 - dice_coef: 0.8225 - val_loss: -0.7969 - val_binary_accuracy: 0.9970 - val_jacard_coef: 0.6746 - val_dice_coef: 0.7998
#
# Epoch 00043: val_loss did not improve from -0.82733
# Epoch 44/100
# 98/98 [==============================] - 81s 830ms/step - loss: -0.8362 - binary_accuracy: 0.9971 - jacard_coef: 0.7249 - dice_coef: 0.8362 - val_loss: -0.7790 - val_binary_accuracy: 0.9965 - val_jacard_coef: 0.6478 - val_dice_coef: 0.7812
#
# Epoch 00044: val_loss did not improve from -0.82733
# Epoch 45/100
# 98/98 [==============================] - 80s 822ms/step - loss: -0.8249 - binary_accuracy: 0.9964 - jacard_coef: 0.7127 - dice_coef: 0.8249 - val_loss: -0.8263 - val_binary_accuracy: 0.9968 - val_jacard_coef: 0.7156 - val_dice_coef: 0.8317
#
# Epoch 00045: val_loss did not improve from -0.82733
# Epoch 46/100
# 98/98 [==============================] - 80s 820ms/step - loss: -0.8196 - binary_accuracy: 0.9966 - jacard_coef: 0.7122 - dice_coef: 0.8196 - val_loss: -0.8198 - val_binary_accuracy: 0.9973 - val_jacard_coef: 0.6994 - val_dice_coef: 0.8181
#
# Epoch 00046: val_loss did not improve from -0.82733
# Epoch 47/100
# 98/98 [==============================] - 81s 829ms/step - loss: -0.8210 - binary_accuracy: 0.9964 - jacard_coef: 0.7065 - dice_coef: 0.8210 - val_loss: -0.8124 - val_binary_accuracy: 0.9969 - val_jacard_coef: 0.6917 - val_dice_coef: 0.8149
#
# Epoch 00047: val_loss did not improve from -0.82733
# Epoch 48/100
# 98/98 [==============================] - 81s 824ms/step - loss: -0.8334 - binary_accuracy: 0.9967 - jacard_coef: 0.7260 - dice_coef: 0.8333 - val_loss: -0.7944 - val_binary_accuracy: 0.9967 - val_jacard_coef: 0.6360 - val_dice_coef: 0.7558
#
# Epoch 00048: val_loss did not improve from -0.82733
# Epoch 49/100
# 98/98 [==============================] - 81s 826ms/step - loss: -0.8340 - binary_accuracy: 0.9969 - jacard_coef: 0.7276 - dice_coef: 0.8340 - val_loss: -0.7601 - val_binary_accuracy: 0.9964 - val_jacard_coef: 0.6149 - val_dice_coef: 0.7556
#
# Epoch 00049: val_loss did not improve from -0.82733
# Epoch 50/100
# 98/98 [==============================] - 81s 827ms/step - loss: -0.8084 - binary_accuracy: 0.9959 - jacard_coef: 0.6941 - dice_coef: 0.8083 - val_loss: -0.7935 - val_binary_accuracy: 0.9969 - val_jacard_coef: 0.6736 - val_dice_coef: 0.7959
#
# Epoch 00050: val_loss did not improve from -0.82733
# Epoch 51/100
# 98/98 [==============================] - 81s 831ms/step - loss: -0.8342 - binary_accuracy: 0.9968 - jacard_coef: 0.7261 - dice_coef: 0.8343 - val_loss: -0.8286 - val_binary_accuracy: 0.9972 - val_jacard_coef: 0.7180 - val_dice_coef: 0.8329
#
# Epoch 00051: val_loss improved from -0.82733 to -0.82856, saving model to ResUNet-segModel-weights.hdf5
# Epoch 52/100
# 98/98 [==============================] - 80s 823ms/step - loss: -0.8351 - binary_accuracy: 0.9969 - jacard_coef: 0.7378 - dice_coef: 0.8350 - val_loss: -0.8192 - val_binary_accuracy: 0.9970 - val_jacard_coef: 0.7110 - val_dice_coef: 0.8260
#
# Epoch 00052: val_loss did not improve from -0.82856
# Epoch 53/100
# 98/98 [==============================] - 82s 836ms/step - loss: -0.8096 - binary_accuracy: 0.9967 - jacard_coef: 0.6928 - dice_coef: 0.8096 - val_loss: -0.8183 - val_binary_accuracy: 0.9969 - val_jacard_coef: 0.6829 - val_dice_coef: 0.8081
#
# Epoch 00053: val_loss did not improve from -0.82856
# Epoch 54/100
# 98/98 [==============================] - 81s 832ms/step - loss: -0.8308 - binary_accuracy: 0.9965 - jacard_coef: 0.7315 - dice_coef: 0.8308 - val_loss: -0.7903 - val_binary_accuracy: 0.9971 - val_jacard_coef: 0.6449 - val_dice_coef: 0.7613
#
# Epoch 00054: val_loss did not improve from -0.82856
# Epoch 55/100
# 98/98 [==============================] - 82s 836ms/step - loss: -0.8252 - binary_accuracy: 0.9970 - jacard_coef: 0.7180 - dice_coef: 0.8250 - val_loss: -0.7952 - val_binary_accuracy: 0.9967 - val_jacard_coef: 0.6717 - val_dice_coef: 0.7986
#
# Epoch 00055: val_loss did not improve from -0.82856
# Epoch 56/100
# 98/98 [==============================] - 82s 835ms/step - loss: -0.8288 - binary_accuracy: 0.9968 - jacard_coef: 0.7195 - dice_coef: 0.8288 - val_loss: -0.8396 - val_binary_accuracy: 0.9971 - val_jacard_coef: 0.7320 - val_dice_coef: 0.8441
#
# Epoch 00056: val_loss improved from -0.82856 to -0.83959, saving model to ResUNet-segModel-weights.hdf5
# Epoch 57/100
# 98/98 [==============================] - 84s 861ms/step - loss: -0.8461 - binary_accuracy: 0.9968 - jacard_coef: 0.7424 - dice_coef: 0.8461 - val_loss: -0.7979 - val_binary_accuracy: 0.9962 - val_jacard_coef: 0.6699 - val_dice_coef: 0.7999
#
# Epoch 00057: val_loss did not improve from -0.83959
# Epoch 58/100
# 98/98 [==============================] - 82s 840ms/step - loss: -0.8279 - binary_accuracy: 0.9964 - jacard_coef: 0.7179 - dice_coef: 0.8279 - val_loss: -0.8054 - val_binary_accuracy: 0.9971 - val_jacard_coef: 0.6724 - val_dice_coef: 0.8019
#
# Epoch 00058: val_loss did not improve from -0.83959
# Epoch 59/100
# 98/98 [==============================] - 82s 841ms/step - loss: -0.8339 - binary_accuracy: 0.9963 - jacard_coef: 0.7286 - dice_coef: 0.8339 - val_loss: -0.8204 - val_binary_accuracy: 0.9966 - val_jacard_coef: 0.7099 - val_dice_coef: 0.8267
#
# Epoch 00059: val_loss did not improve from -0.83959
# Epoch 60/100
# 98/98 [==============================] - 83s 845ms/step - loss: -0.8354 - binary_accuracy: 0.9970 - jacard_coef: 0.7287 - dice_coef: 0.8354 - val_loss: -0.8264 - val_binary_accuracy: 0.9970 - val_jacard_coef: 0.7115 - val_dice_coef: 0.8289
#
# Epoch 00060: val_loss did not improve from -0.83959
# Epoch 61/100
# 98/98 [==============================] - 82s 840ms/step - loss: -0.8299 - binary_accuracy: 0.9968 - jacard_coef: 0.7208 - dice_coef: 0.8299 - val_loss: -0.7806 - val_binary_accuracy: 0.9966 - val_jacard_coef: 0.6424 - val_dice_coef: 0.7775
#
# Epoch 00061: val_loss did not improve from -0.83959
# Epoch 62/100
# 98/98 [==============================] - 81s 826ms/step - loss: -0.8493 - binary_accuracy: 0.9972 - jacard_coef: 0.7449 - dice_coef: 0.8493 - val_loss: -0.8346 - val_binary_accuracy: 0.9970 - val_jacard_coef: 0.7201 - val_dice_coef: 0.8345
#
# Epoch 00062: val_loss did not improve from -0.83959
# Epoch 63/100
# 98/98 [==============================] - 81s 831ms/step - loss: -0.8055 - binary_accuracy: 0.9967 - jacard_coef: 0.6987 - dice_coef: 0.8055 - val_loss: -0.7921 - val_binary_accuracy: 0.9969 - val_jacard_coef: 0.6422 - val_dice_coef: 0.7700
#
# Epoch 00063: val_loss did not improve from -0.83959
# Epoch 64/100
# 98/98 [==============================] - 81s 832ms/step - loss: -0.8434 - binary_accuracy: 0.9969 - jacard_coef: 0.7432 - dice_coef: 0.8434 - val_loss: -0.8256 - val_binary_accuracy: 0.9972 - val_jacard_coef: 0.7147 - val_dice_coef: 0.8304
#
# Epoch 00064: val_loss did not improve from -0.83959
# Epoch 65/100
# 98/98 [==============================] - 82s 842ms/step - loss: -0.8451 - binary_accuracy: 0.9971 - jacard_coef: 0.7447 - dice_coef: 0.8450 - val_loss: -0.8455 - val_binary_accuracy: 0.9974 - val_jacard_coef: 0.7351 - val_dice_coef: 0.8459
#
# Epoch 00065: val_loss improved from -0.83959 to -0.84554, saving model to ResUNet-segModel-weights.hdf5
# Epoch 66/100
# 98/98 [==============================] - 81s 827ms/step - loss: -0.8423 - binary_accuracy: 0.9965 - jacard_coef: 0.7396 - dice_coef: 0.8423 - val_loss: -0.8175 - val_binary_accuracy: 0.9972 - val_jacard_coef: 0.6794 - val_dice_coef: 0.7945
#
# Epoch 00066: val_loss did not improve from -0.84554
# Epoch 67/100
# 98/98 [==============================] - 83s 847ms/step - loss: -0.8671 - binary_accuracy: 0.9974 - jacard_coef: 0.7700 - dice_coef: 0.8671 - val_loss: -0.7920 - val_binary_accuracy: 0.9972 - val_jacard_coef: 0.6644 - val_dice_coef: 0.7906
#
# Epoch 00067: val_loss did not improve from -0.84554
# Epoch 68/100
# 98/98 [==============================] - 82s 841ms/step - loss: -0.8674 - binary_accuracy: 0.9974 - jacard_coef: 0.7719 - dice_coef: 0.8675 - val_loss: -0.8342 - val_binary_accuracy: 0.9975 - val_jacard_coef: 0.7277 - val_dice_coef: 0.8401
#
# Epoch 00068: val_loss did not improve from -0.84554
# Epoch 69/100
# 98/98 [==============================] - 82s 841ms/step - loss: -0.8557 - binary_accuracy: 0.9967 - jacard_coef: 0.7578 - dice_coef: 0.8558 - val_loss: -0.8430 - val_binary_accuracy: 0.9974 - val_jacard_coef: 0.7394 - val_dice_coef: 0.8472
#
# Epoch 00069: val_loss did not improve from -0.84554
# Epoch 70/100
# 98/98 [==============================] - 82s 838ms/step - loss: -0.8498 - binary_accuracy: 0.9975 - jacard_coef: 0.7469 - dice_coef: 0.8498 - val_loss: -0.8335 - val_binary_accuracy: 0.9973 - val_jacard_coef: 0.7205 - val_dice_coef: 0.8351
#
# Epoch 00070: val_loss did not improve from -0.84554
# Epoch 71/100
# 98/98 [==============================] - 82s 842ms/step - loss: -0.8315 - binary_accuracy: 0.9972 - jacard_coef: 0.7395 - dice_coef: 0.8315 - val_loss: -0.8475 - val_binary_accuracy: 0.9972 - val_jacard_coef: 0.7374 - val_dice_coef: 0.8467
#
# Epoch 00071: val_loss improved from -0.84554 to -0.84745, saving model to ResUNet-segModel-weights.hdf5
# Epoch 72/100
# 98/98 [==============================] - 82s 840ms/step - loss: -0.8560 - binary_accuracy: 0.9972 - jacard_coef: 0.7567 - dice_coef: 0.8560 - val_loss: -0.8256 - val_binary_accuracy: 0.9968 - val_jacard_coef: 0.7067 - val_dice_coef: 0.8252
#
# Epoch 00072: val_loss did not improve from -0.84745
# Epoch 73/100
# 98/98 [==============================] - 82s 841ms/step - loss: -0.8361 - binary_accuracy: 0.9965 - jacard_coef: 0.7346 - dice_coef: 0.8360 - val_loss: -0.8121 - val_binary_accuracy: 0.9970 - val_jacard_coef: 0.6880 - val_dice_coef: 0.8131
#
# Epoch 00073: val_loss did not improve from -0.84745
# Epoch 74/100
# 98/98 [==============================] - 82s 835ms/step - loss: -0.8473 - binary_accuracy: 0.9968 - jacard_coef: 0.7404 - dice_coef: 0.8473 - val_loss: -0.8369 - val_binary_accuracy: 0.9971 - val_jacard_coef: 0.7297 - val_dice_coef: 0.8416
#
# Epoch 00074: val_loss did not improve from -0.84745
# Epoch 75/100
# 98/98 [==============================] - 82s 840ms/step - loss: -0.8610 - binary_accuracy: 0.9973 - jacard_coef: 0.7642 - dice_coef: 0.8610 - val_loss: -0.8263 - val_binary_accuracy: 0.9976 - val_jacard_coef: 0.7187 - val_dice_coef: 0.8327
#
# Epoch 00075: val_loss did not improve from -0.84745
# Epoch 76/100
# 98/98 [==============================] - 82s 838ms/step - loss: -0.8504 - binary_accuracy: 0.9969 - jacard_coef: 0.7601 - dice_coef: 0.8504 - val_loss: -0.8214 - val_binary_accuracy: 0.9971 - val_jacard_coef: 0.7175 - val_dice_coef: 0.8283
#
# Epoch 00076: val_loss did not improve from -0.84745
# Epoch 77/100
# 98/98 [==============================] - 84s 855ms/step - loss: -0.8595 - binary_accuracy: 0.9970 - jacard_coef: 0.7637 - dice_coef: 0.8593 - val_loss: -0.6840 - val_binary_accuracy: 0.9930 - val_jacard_coef: 0.5256 - val_dice_coef: 0.6835
#
# Epoch 00077: val_loss did not improve from -0.84745
# Epoch 78/100
# 98/98 [==============================] - 84s 856ms/step - loss: -0.8351 - binary_accuracy: 0.9969 - jacard_coef: 0.7323 - dice_coef: 0.8351 - val_loss: -0.8418 - val_binary_accuracy: 0.9973 - val_jacard_coef: 0.7324 - val_dice_coef: 0.8440
#
# Epoch 00078: val_loss did not improve from -0.84745
# Epoch 79/100
# 98/98 [==============================] - 82s 843ms/step - loss: -0.8360 - binary_accuracy: 0.9973 - jacard_coef: 0.7380 - dice_coef: 0.8360 - val_loss: -0.8106 - val_binary_accuracy: 0.9969 - val_jacard_coef: 0.6789 - val_dice_coef: 0.8054
#
# Epoch 00079: val_loss did not improve from -0.84745
# Epoch 80/100
# 98/98 [==============================] - 83s 847ms/step - loss: -0.8670 - binary_accuracy: 0.9974 - jacard_coef: 0.7704 - dice_coef: 0.8670 - val_loss: -0.8084 - val_binary_accuracy: 0.9971 - val_jacard_coef: 0.6905 - val_dice_coef: 0.8126
#
# Epoch 00080: val_loss did not improve from -0.84745
# Epoch 81/100
# 98/98 [==============================] - 82s 841ms/step - loss: -0.8545 - binary_accuracy: 0.9972 - jacard_coef: 0.7567 - dice_coef: 0.8545 - val_loss: -0.8182 - val_binary_accuracy: 0.9969 - val_jacard_coef: 0.6839 - val_dice_coef: 0.8084
#
# Epoch 00081: val_loss did not improve from -0.84745
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 00081: early stopping

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['jacard_coef']);
plt.plot(history.history['val_jacard_coef']);
plt.title("SEG ResUNet Model jacard_coef");
plt.ylabel("jacard_coef");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

plt.subplot(1,2,2)
plt.plot(history.history['dice_coef']);
plt.plot(history.history['val_dice_coef']);
plt.title("SEG ResUNet Model dice_coef");
plt.ylabel("dice_coef");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %%
test_gen = train_generator(X_test,BATCH_SIZE,
                           dict(),
                           target_size = (256,256))
results = res_unet_model.evaluate(test_gen,steps = len(X_test) / BATCH_SIZE)
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 12/12 [==============================] - 4s 339ms/step - loss: -0.8438 - binary_accuracy: 0.9970 - jacard_coef: 0.7390 - dice_coef: 0.8474

# %%
for i in range(30):
    index=np.random.randint(1,len(X_test.index))
    img = cv2.imread(X_test['image_path'].iloc[index])
    img = cv2.resize(img ,(256, 256))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=res_unet_model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(X_test['mask_path'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
